# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.18.0

# %%
import numpy as np
import pandas as pd
import cv2
import os
import math
import copy
import imageio
import seaborn as sns
from glob import glob
from pathlib import Path
from collections import deque
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
from IPython.display import Image
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# %%
import seaborn as sns
import plotly.express as px
from IPython.display import SVG
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots
# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.applications import VGG16, inception_v3
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import RMSprop, Adam, SGD
from tensorflow.keras.layers import Input, Lambda, Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, MaxPooling2D, \
    Permute, TimeDistributed, Bidirectional, GRU, SimpleRNN, LSTM, GlobalAveragePooling2D, SeparableConv2D, ZeroPadding2D, Convolution2D, ZeroPadding2D, \
    Reshape, Conv2DTranspose, LeakyReLU, Conv1D, AveragePooling1D, MaxPooling1D, Activation, Conv3D, MaxPooling3D

# %%
Main_Video_Path = Path("./dataset/anomaly1")
Video_Path = list(Main_Video_Path.glob(r"*/*.mp4"))
Video_Labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1],Video_Path))
Video_Path_Series = pd.Series(Video_Path,name="MP4").astype(str)
Video_Labels_Series = pd.Series(Video_Labels,name="CATEGORY")
Main_MP4_Data = pd.concat([Video_Path_Series,Video_Labels_Series],axis=1)

# %%
Anomaly_Data = Main_MP4_Data[Main_MP4_Data["CATEGORY"] == "fight"]
NonAnomaly_Data = Main_MP4_Data[Main_MP4_Data["CATEGORY"] == "noFight"]

Anomaly_Data = Anomaly_Data.reset_index()
NonAnomaly_Data = NonAnomaly_Data.reset_index()

# %%
Anomaly_Data
# Out:
#      index                               MP4 CATEGORY
# 0        0  dataset\anomaly1\fight\fi001.mp4    fight
# 1        1  dataset\anomaly1\fight\fi002.mp4    fight
# 2        2  dataset\anomaly1\fight\fi003.mp4    fight
# 3        3  dataset\anomaly1\fight\fi004.mp4    fight
# 4        4  dataset\anomaly1\fight\fi005.mp4    fight
# ..     ...                               ...      ...
# 145    145  dataset\anomaly1\fight\fi146.mp4    fight
# 146    146  dataset\anomaly1\fight\fi147.mp4    fight
# 147    147  dataset\anomaly1\fight\fi148.mp4    fight
# 148    148  dataset\anomaly1\fight\fi149.mp4    fight
# 149    149  dataset\anomaly1\fight\fi150.mp4    fight
#
# [150 rows x 3 columns]

# %%
NonAnomaly_Data
# Out:
#      index                                   MP4 CATEGORY
# 0      150  dataset\anomaly1\noFight\nofi001.mp4  noFight
# 1      151  dataset\anomaly1\noFight\nofi002.mp4  noFight
# 2      152  dataset\anomaly1\noFight\nofi003.mp4  noFight
# 3      153  dataset\anomaly1\noFight\nofi004.mp4  noFight
# 4      154  dataset\anomaly1\noFight\nofi005.mp4  noFight
# ..     ...                                   ...      ...
# 145    295  dataset\anomaly1\noFight\nofi146.mp4  noFight
# 146    296  dataset\anomaly1\noFight\nofi147.mp4  noFight
# 147    297  dataset\anomaly1\noFight\nofi148.mp4  noFight
# 148    298  dataset\anomaly1\noFight\nofi149.mp4  noFight
# 149    299  dataset\anomaly1\noFight\nofi150.mp4  noFight
#
# [150 rows x 3 columns]

# %%
Main_Video_Path = Path("./dataset/anomaly2/Real Life Violence Dataset")
Video_Path = list(Main_Video_Path.glob(r"*/*.mp4"))
Video_Labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1],Video_Path))
Video_Path_Series = pd.Series(Video_Path,name="MP4").astype(str)
Video_Labels_Series = pd.Series(Video_Labels,name="CATEGORY")
Main_MP4_Data = pd.concat([Video_Path_Series,Video_Labels_Series],axis=1)

# %%
Main_MP4_Data["CATEGORY"].replace({'Violence':'fight','NonViolence':'noFight'}, inplace=True)
AD = Main_MP4_Data[Main_MP4_Data["CATEGORY"] == "fight"]
NAD = Main_MP4_Data[Main_MP4_Data["CATEGORY"] == "noFight"]
# Out:
# C:\Users\srhan\AppData\Local\Temp\ipykernel_27432\50674731.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Main_MP4_Data["CATEGORY"].replace({'Violence':'fight','NonViolence':'noFight'}, inplace=True)

# %%
AD
# Out:
#                                                     MP4 CATEGORY
# 951   dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 952   dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 953   dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 954   dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 955   dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# ...                                                 ...      ...
# 1946  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 1947  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 1948  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 1949  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 1950  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
#
# [1000 rows x 2 columns]

# %%
NAD
# Out:
#                                                    MP4 CATEGORY
# 0    dataset\anomaly2\Real Life Violence Dataset\No...  noFight
# 1    dataset\anomaly2\Real Life Violence Dataset\No...  noFight
# 2    dataset\anomaly2\Real Life Violence Dataset\No...  noFight
# 3    dataset\anomaly2\Real Life Violence Dataset\No...  noFight
# 4    dataset\anomaly2\Real Life Violence Dataset\No...  noFight
# ..                                                 ...      ...
# 946  dataset\anomaly2\Real Life Violence Dataset\No...  noFight
# 947  dataset\anomaly2\Real Life Violence Dataset\No...  noFight
# 948  dataset\anomaly2\Real Life Violence Dataset\No...  noFight
# 949  dataset\anomaly2\Real Life Violence Dataset\No...  noFight
# 950  dataset\anomaly2\Real Life Violence Dataset\No...  noFight
#
# [951 rows x 2 columns]

# %%
Anomaly_Data = pd.concat([Anomaly_Data, AD], ignore_index=True, sort=False)
NonAnomaly_Data = pd.concat([NonAnomaly_Data, NAD], ignore_index=True, sort=False)

# %%
Anomaly_Data
# Out:
#       index                                                MP4 CATEGORY
# 0       0.0                   dataset\anomaly1\fight\fi001.mp4    fight
# 1       1.0                   dataset\anomaly1\fight\fi002.mp4    fight
# 2       2.0                   dataset\anomaly1\fight\fi003.mp4    fight
# 3       3.0                   dataset\anomaly1\fight\fi004.mp4    fight
# 4       4.0                   dataset\anomaly1\fight\fi005.mp4    fight
# ...     ...                                                ...      ...
# 1145    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 1146    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 1147    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 1148    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 1149    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
#
# [1150 rows x 3 columns]

# %%
NonAnomaly_Data
# Out:
#       index                                                MP4 CATEGORY
# 0     150.0               dataset\anomaly1\noFight\nofi001.mp4  noFight
# 1     151.0               dataset\anomaly1\noFight\nofi002.mp4  noFight
# 2     152.0               dataset\anomaly1\noFight\nofi003.mp4  noFight
# 3     153.0               dataset\anomaly1\noFight\nofi004.mp4  noFight
# 4     154.0               dataset\anomaly1\noFight\nofi005.mp4  noFight
# ...     ...                                                ...      ...
# 1096    NaN  dataset\anomaly2\Real Life Violence Dataset\No...  noFight
# 1097    NaN  dataset\anomaly2\Real Life Violence Dataset\No...  noFight
# 1098    NaN  dataset\anomaly2\Real Life Violence Dataset\No...  noFight
# 1099    NaN  dataset\anomaly2\Real Life Violence Dataset\No...  noFight
# 1100    NaN  dataset\anomaly2\Real Life Violence Dataset\No...  noFight
#
# [1101 rows x 3 columns]

# %% [markdown]
# **Merging all different Data**

# %%
Cdata = NonAnomaly_Data

# %%
Cdata = pd.concat([NonAnomaly_Data, Anomaly_Data], ignore_index=True, sort=False)

# %%
Cdata
# Out:
#       index                                                MP4 CATEGORY
# 0     150.0               dataset\anomaly1\noFight\nofi001.mp4  noFight
# 1     151.0               dataset\anomaly1\noFight\nofi002.mp4  noFight
# 2     152.0               dataset\anomaly1\noFight\nofi003.mp4  noFight
# 3     153.0               dataset\anomaly1\noFight\nofi004.mp4  noFight
# 4     154.0               dataset\anomaly1\noFight\nofi005.mp4  noFight
# ...     ...                                                ...      ...
# 2246    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 2247    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 2248    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 2249    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 2250    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
#
# [2251 rows x 3 columns]

# %%
Cdata["CATEGORY"].replace({'fight':1,'noFight':0}, inplace=True)
# Out:
# C:\Users\srhan\AppData\Local\Temp\ipykernel_27432\1989987325.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Cdata["CATEGORY"].replace({'fight':1,'noFight':0}, inplace=True)
# C:\Users\srhan\AppData\Local\Temp\ipykernel_27432\1989987325.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Cdata["CATEGORY"].replace({'fight':1,'noFight':0}, inplace=True)

# %%
Cdata
# Out:
#       index                                                MP4  CATEGORY
# 0     150.0               dataset\anomaly1\noFight\nofi001.mp4         0
# 1     151.0               dataset\anomaly1\noFight\nofi002.mp4         0
# 2     152.0               dataset\anomaly1\noFight\nofi003.mp4         0
# 3     153.0               dataset\anomaly1\noFight\nofi004.mp4         0
# 4     154.0               dataset\anomaly1\noFight\nofi005.mp4         0
# ...     ...                                                ...       ...
# 2246    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...         1
# 2247    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...         1
# 2248    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...         1
# 2249    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...         1
# 2250    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...         1
#
# [2251 rows x 3 columns]

# %% [markdown]
# ## **Video Preprocessing**

# %%
Anomaly_Data.MP4[1]
# Out:
# 'dataset\\anomaly1\\fight\\fi002.mp4'

# %%
import os

os.makedirs('./dataset/Frames', exist_ok=True)

# %%
a_train,a_valid = train_test_split(Anomaly_Data.MP4, test_size=0.1,random_state=17)
print("a_train {} samples , a_valid {} samples".format(len(a_train),len(a_valid)))
# Out:
# a_train 1035 samples , a_valid 115 samples

# %%
na_train,na_valid = train_test_split(NonAnomaly_Data.MP4, test_size=0.1,random_state=17)
print("na_train {} samples , na_valid {} samples".format(len(na_train),len(na_valid)))
# Out:
# na_train 990 samples , na_valid 111 samples

# %%
os.mkdir("./dataset/Frames/train")
os.mkdir("./dataset/Frames/test")
os.mkdir("./dataset/Frames/train/nonanomaly")
os.mkdir("./dataset/Frames/train/anomaly")
os.mkdir("./dataset/Frames/test/nonanomaly")
os.mkdir("./dataset/Frames/test/anomaly")

# %%
def make_frames(df,tag,sset):
    a = 0
    for file_video in df:
        Video_File_Path = file_video

        Video_Caption = cv2.VideoCapture(Video_File_Path)
        Frame_Rate = 15
        count = 0
        temp = []
        if Video_Caption.isOpened():
            os.mkdir('./dataset/Frames/{}/{}/a{}'.format(sset,tag,a))
        while Video_Caption.isOpened():

            Current_Frame_ID = Video_Caption.get(1)

            ret,frame = Video_Caption.read()

            if ret != True:
                break

            if Current_Frame_ID % math.floor(Frame_Rate) == 0:
                image = cv2.resize(frame,(256,256))
                cv2.imwrite("./dataset/Frames/{}/{}/a{}/frame{}.jpg".format(sset,tag,a,count), image)
                count += 1
        a += 1

        Video_Caption.release()

# %%
make_frames(a_train,tag='anomaly',sset='train')

# %%
make_frames(a_valid,tag='anomaly',sset='test')

# %%
make_frames(na_train,tag='nonanomaly',sset='train')

# %%
make_frames(na_valid,tag='nonanomaly',sset='test')

# %%
sorted(os.listdir("./dataset/Frames/test"))
# Out:
# ['anomaly', 'nonanomaly']

# %%
class Config():
    def __init__(self):
        pass

    num_classes=2
    labels_to_class = {0:'nonanomaly',1:'anomaly'}
    class_to_labels = {'nonanomaly':0,'anomaly':1}
    resize = 224
    num_epochs =10
    batch_size =10

# %%
train_data_path = './dataset/Frames/train'
test_data_path = "./dataset/Frames/test"

# %%
if not os.path.exists('data_files'):
    os.mkdir('data_files')
if not os.path.exists('data_files/train'):
    os.mkdir('data_files/train')
if not os.path.exists('data_files/test'):
    os.mkdir('data_files/test')

# %%
num_classes = 2
labels_name={'nonanomaly':0,'anomaly':1}

# %%
data_dir_list = os.listdir(train_data_path)
data_dir_list
# Out:
# ['anomaly', 'nonanomaly']

# %%
import os
import pandas as pd

def make_train(train_data_path):
    data_dir_list = os.listdir(train_data_path)
    for data_dir in data_dir_list:  # looping over every activity
        label = labels_name[str(data_dir)]
        video_list = os.listdir(os.path.join(train_data_path, data_dir))
        for vid in video_list:  # looping over every video within an activity
            train_df = pd.DataFrame(columns=['FileName', 'Label', 'ClassName'])
            img_list = os.listdir(os.path.join(train_data_path, data_dir, vid))
            for img in img_list:  # looping over every frame within the video
                img_path = os.path.join(train_data_path, data_dir, vid, img)
                # Create a temporary DataFrame for the new row
                new_row = pd.DataFrame({'FileName': [img_path], 'Label': [label], 'ClassName': [data_dir]})
                # Concatenate with the existing DataFrame
                train_df = pd.concat([train_df, new_row], ignore_index=True)
            file_name = '{}_{}.csv'.format(data_dir, vid)
            train_df.to_csv('data_files/train/{}'.format(file_name), index=False)

make_train(train_data_path)

# %%
def make_test(test_data_path):
    data_dir_list = os.listdir(test_data_path)
    for data_dir in data_dir_list:  # looping over every activity
        label = labels_name[str(data_dir)]
        video_list = os.listdir(os.path.join(test_data_path, data_dir))
        for vid in video_list:  # looping over every video within an activity
            test_df = pd.DataFrame(columns=['FileName', 'Label', 'ClassName'])
            img_list = os.listdir(os.path.join(test_data_path, data_dir, vid))
            for img in img_list:  # looping over every frame within the video
                img_path = os.path.join(test_data_path, data_dir, vid, img)
                # Create a temporary DataFrame for the new row
                new_row = pd.DataFrame({'FileName': [img_path], 'Label': [label], 'ClassName': [data_dir]})
                # Concatenate with the existing DataFrame
                test_df = pd.concat([test_df, new_row], ignore_index=True)
            file_name = '{}_{}.csv'.format(data_dir, vid)
            test_df.to_csv('data_files/test/{}'.format(file_name), index=False)

make_test(test_data_path)

# %%
class ActionDataGenerator(object):
    def __init__(self, root_data_path, temporal_stride=1, temporal_length=16, resize=224):
        self.root_data_path = root_data_path
        self.temporal_length = temporal_length
        self.temporal_stride = temporal_stride
        self.resize = resize

    def file_generator(self, data_path, data_files):
        '''
        data_files - list of csv files to be read.
        '''
        if not data_files:
            print("Warning: No data files found in", data_path)
            return

        for f in data_files:
            try:
                file_path = os.path.join(data_path, f)
                if not os.path.exists(file_path):
                    print(f"Warning: File {file_path} does not exist")
                    continue

                tmp_df = pd.read_csv(file_path)
                if tmp_df.empty:
                    print(f"Warning: Empty CSV file - {f}")
                    continue

                label_list = list(tmp_df['Label'])
                total_images = len(label_list)

                if total_images >= self.temporal_length:
                    num_samples = int((total_images-self.temporal_length)/self.temporal_stride)+1
                    print(f'Processing file {f} with {num_samples} samples')
                    img_list = list(tmp_df['FileName'])
                else:
                    print(f'Skipping file {f} - too few frames ({total_images} < {self.temporal_length})')
                    continue

                samples = deque(maxlen=self.temporal_length)
                for img in img_list:
                    if not os.path.exists(img):
                        print(f"Warning: Image file does not exist - {img}")
                        continue
                    samples.append(img)
                    if len(samples) == self.temporal_length:
                        samples_c = copy.deepcopy(samples)
                        yield list(samples_c), label_list[0]
                        for _ in range(self.temporal_stride):
                            if samples:
                                samples.popleft()

            except Exception as e:
                print(f"Error processing file {f}: {str(e)}")
                continue

    def load_samples(self, data_cat='train'):
        data_path = os.path.join(self.root_data_path, data_cat)
        if not os.path.exists(data_path):
            raise ValueError(f"Data path does not exist: {data_path}")

        csv_data_files = os.listdir(data_path)
        if not csv_data_files:
            raise ValueError(f"No files found in {data_path}")

        print(f"Found {len(csv_data_files)} files in {data_path}")

        file_gen = self.file_generator(data_path, csv_data_files)
        data_list = []

        for x, y in file_gen:
            data_list.append([x, y])

        if not data_list:
            raise ValueError("No valid samples were generated")

        print(f"Generated {len(data_list)} samples from {data_path}")
        return data_list

    def data_generator(self, data, batch_size=10, shuffle=True):
        """
        Yields the next training batch.
        """
        if not data:
            raise ValueError("Empty data provided to generator")

        num_samples = len(data)
        if shuffle:
            data = self.shuffle_data(data)

        while True:
            for offset in range(0, num_samples, batch_size):
                batch_samples = data[offset:offset+batch_size]
                X_train = []
                y_train = []

                for batch_sample in batch_samples:
                    try:
                        x = batch_sample[0]
                        y = batch_sample[1]
                        temp_data_list = []

                        for img_path in x:
                            try:
                                if not os.path.exists(img_path):
                                    raise FileNotFoundError(f"Image not found: {img_path}")

                                img = cv2.imread(img_path)
                                if img is None:
                                    raise ValueError(f"Failed to read image: {img_path}")

                                img = self.preprocess_image(img)
                                temp_data_list.append(img)

                            except Exception as e:
                                print(f"Error processing image {img_path}: {str(e)}")
                                raise

                        if len(temp_data_list) == self.temporal_length:
                            X_train.append(temp_data_list)
                            y_train.append(y)

                    except Exception as e:
                        print(f"Error processing batch sample: {str(e)}")
                        continue

                if not X_train or not y_train:
                    print("Warning: Empty batch generated, skipping...")
                    continue

                X_train = np.array(X_train)
                y_train = np.array(y_train)
                y_train = to_categorical(y_train, 2)

                yield X_train, y_train

    def shuffle_data(self, samples):
        return shuffle(samples, random_state=2)

    def preprocess_image(self, img):
        img = cv2.resize(img, (self.resize, self.resize))
        img = img/255.0
        return img

# %%
# Set your paths
root_data_path = 'data_files'
train_data_path = 'path/to/your/train/data'
test_data_path = 'path/to/your/test/data'

# Create directories if they don't exist
os.makedirs('data_files/train', exist_ok=True)
os.makedirs('data_files/test', exist_ok=True)

# %%
data_gen_obj = ActionDataGenerator(root_data_path, temporal_stride=2, temporal_length=5)

# %%
train_data = data_gen_obj.load_samples(data_cat='train')

test_data = data_gen_obj.load_samples(data_cat='test')
# Out:
# Found 2025 files in data_files\train
# Processing file anomaly_a0.csv with 3 samples
# Processing file anomaly_a1.csv with 2 samples
# Processing file anomaly_a10.csv with 5 samples
# Processing file anomaly_a100.csv with 3 samples
# Processing file anomaly_a1000.csv with 3 samples
# Processing file anomaly_a1001.csv with 2 samples
# Processing file anomaly_a1002.csv with 3 samples
# Processing file anomaly_a1003.csv with 4 samples
# Processing file anomaly_a1004.csv with 4 samples
# Processing file anomaly_a1005.csv with 3 samples
# Processing file anomaly_a1006.csv with 3 samples
# Processing file anomaly_a1007.csv with 4 samples
# Processing file anomaly_a1008.csv with 3 samples
# Processing file anomaly_a1009.csv with 4 samples
# Processing file anomaly_a101.csv with 1 samples
# Processing file anomaly_a1010.csv with 4 samples
# Processing file anomaly_a1011.csv with 3 samples
# Processing file anomaly_a1012.csv with 3 samples
# Processing file anomaly_a1013.csv with 4 samples
# Processing file anomaly_a1014.csv with 3 samples
# Skipping file anomaly_a1015.csv - too few frames (4 < 5)
# Processing file anomaly_a1016.csv with 3 samples
# Processing file anomaly_a1017.csv with 5 samples
# Processing file anomaly_a1018.csv with 2 samples
# Processing file anomaly_a1019.csv with 2 samples
# Processing file anomaly_a102.csv with 4 samples
# Skipping file anomaly_a1020.csv - too few frames (4 < 5)
# Processing file anomaly_a1021.csv with 5 samples
# Processing file anomaly_a1022.csv with 135 samples
# Processing file anomaly_a1023.csv with 3 samples
# Processing file anomaly_a1024.csv with 3 samples
# Processing file anomaly_a1025.csv with 3 samples
# Processing file anomaly_a1026.csv with 4 samples
# Processing file anomaly_a1027.csv with 3 samples
# Processing file anomaly_a1028.csv with 4 samples
# Processing file anomaly_a1029.csv with 3 samples
# Processing file anomaly_a103.csv with 2 samples
# Processing file anomaly_a1030.csv with 2 samples
# Processing file anomaly_a1031.csv with 3 samples
# Processing file anomaly_a1032.csv with 4 samples
# Skipping file anomaly_a1033.csv - too few frames (4 < 5)
# Processing file anomaly_a1034.csv with 3 samples
# Processing file anomaly_a104.csv with 3 samples
# Processing file anomaly_a105.csv with 4 samples
# Processing file anomaly_a106.csv with 2 samples
# Processing file anomaly_a107.csv with 3 samples
# Processing file anomaly_a108.csv with 3 samples
# Processing file anomaly_a109.csv with 3 samples
# Skipping file anomaly_a11.csv - too few frames (4 < 5)
# Processing file anomaly_a110.csv with 3 samples
# Processing file anomaly_a111.csv with 4 samples
# Processing file anomaly_a112.csv with 4 samples
# Processing file anomaly_a113.csv with 3 samples
# Processing file anomaly_a114.csv with 4 samples
# Processing file anomaly_a115.csv with 3 samples
# Processing file anomaly_a116.csv with 2 samples
# Processing file anomaly_a117.csv with 3 samples
# Processing file anomaly_a118.csv with 3 samples
# Processing file anomaly_a119.csv with 2 samples
# Processing file anomaly_a12.csv with 3 samples
# Processing file anomaly_a120.csv with 3 samples
# Processing file anomaly_a121.csv with 5 samples
# Processing file anomaly_a122.csv with 4 samples
# Processing file anomaly_a123.csv with 4 samples
# Skipping file anomaly_a124.csv - too few frames (4 < 5)
# Processing file anomaly_a125.csv with 3 samples
# Processing file anomaly_a126.csv with 3 samples
# Processing file anomaly_a127.csv with 2 samples
# Processing file anomaly_a128.csv with 4 samples
# Processing file anomaly_a129.csv with 4 samples
# Processing file anomaly_a13.csv with 1 samples
# Skipping file anomaly_a130.csv - too few frames (4 < 5)
# Skipping file anomaly_a131.csv - too few frames (4 < 5)
# Processing file anomaly_a132.csv with 3 samples
# Processing file anomaly_a133.csv with 4 samples
# Processing file anomaly_a134.csv with 3 samples
# Processing file anomaly_a135.csv with 3 samples
# Processing file anomaly_a136.csv with 4 samples
# Processing file anomaly_a137.csv with 3 samples
# Processing file anomaly_a138.csv with 3 samples
# Processing file anomaly_a139.csv with 2 samples
# Processing file anomaly_a14.csv with 1 samples
# Processing file anomaly_a140.csv with 4 samples
# Processing file anomaly_a141.csv with 2 samples
# Processing file anomaly_a142.csv with 3 samples
# Processing file anomaly_a143.csv with 4 samples
# Processing file anomaly_a144.csv with 2 samples
# Processing file anomaly_a145.csv with 3 samples
# Processing file anomaly_a146.csv with 3 samples
# Processing file anomaly_a147.csv with 2 samples
# Processing file anomaly_a148.csv with 1 samples
# Skipping file anomaly_a149.csv - too few frames (4 < 5)
# Processing file anomaly_a15.csv with 4 samples
# Processing file anomaly_a150.csv with 5 samples
# Processing file anomaly_a151.csv with 3 samples
# Processing file anomaly_a152.csv with 5 samples
# Processing file anomaly_a153.csv with 5 samples
# Processing file anomaly_a154.csv with 3 samples
# Processing file anomaly_a155.csv with 3 samples
# Skipping file anomaly_a156.csv - too few frames (4 < 5)
# Processing file anomaly_a157.csv with 3 samples
# Processing file anomaly_a158.csv with 5 samples
# Processing file anomaly_a159.csv with 4 samples
# Processing file anomaly_a16.csv with 3 samples
# Processing file anomaly_a160.csv with 2 samples
# Processing file anomaly_a161.csv with 5 samples
# Processing file anomaly_a162.csv with 3 samples
# Processing file anomaly_a163.csv with 4 samples
# Processing file anomaly_a164.csv with 3 samples
# Processing file anomaly_a165.csv with 3 samples
# Processing file anomaly_a166.csv with 3 samples
# Processing file anomaly_a167.csv with 3 samples
# Processing file anomaly_a168.csv with 2 samples
# Processing file anomaly_a169.csv with 3 samples
# Processing file anomaly_a17.csv with 3 samples
# Processing file anomaly_a170.csv with 1 samples
# Processing file anomaly_a171.csv with 4 samples
# Processing file anomaly_a172.csv with 3 samples
# Processing file anomaly_a173.csv with 4 samples
# Processing file anomaly_a174.csv with 5 samples
# Processing file anomaly_a175.csv with 3 samples
# Processing file anomaly_a176.csv with 4 samples
# Processing file anomaly_a177.csv with 5 samples
# Skipping file anomaly_a178.csv - too few frames (3 < 5)
# Processing file anomaly_a179.csv with 5 samples
# Processing file anomaly_a18.csv with 5 samples
# Processing file anomaly_a180.csv with 2 samples
# Processing file anomaly_a181.csv with 4 samples
# Processing file anomaly_a182.csv with 4 samples
# Processing file anomaly_a183.csv with 3 samples
# Processing file anomaly_a184.csv with 3 samples
# Processing file anomaly_a185.csv with 4 samples
# Processing file anomaly_a186.csv with 5 samples
# Skipping file anomaly_a187.csv - too few frames (4 < 5)
# Skipping file anomaly_a188.csv - too few frames (4 < 5)
# Processing file anomaly_a189.csv with 2 samples
# Processing file anomaly_a19.csv with 4 samples
# Processing file anomaly_a190.csv with 3 samples
# Processing file anomaly_a191.csv with 5 samples
# Processing file anomaly_a192.csv with 2 samples
# Processing file anomaly_a193.csv with 3 samples
# Processing file anomaly_a194.csv with 4 samples
# Skipping file anomaly_a195.csv - too few frames (4 < 5)
# Processing file anomaly_a196.csv with 5 samples
# Processing file anomaly_a197.csv with 6 samples
# Processing file anomaly_a198.csv with 4 samples
# Skipping file anomaly_a199.csv - too few frames (4 < 5)
# Processing file anomaly_a2.csv with 3 samples
# Processing file anomaly_a20.csv with 3 samples
# Skipping file anomaly_a200.csv - too few frames (4 < 5)
# Processing file anomaly_a201.csv with 5 samples
# Processing file anomaly_a202.csv with 5 samples
# Processing file anomaly_a203.csv with 1 samples
# Processing file anomaly_a204.csv with 3 samples
# Processing file anomaly_a205.csv with 3 samples
# Processing file anomaly_a206.csv with 1 samples
# Processing file anomaly_a207.csv with 3 samples
# Processing file anomaly_a208.csv with 2 samples
# Processing file anomaly_a209.csv with 3 samples
# Processing file anomaly_a21.csv with 4 samples
# Processing file anomaly_a210.csv with 4 samples
# Processing file anomaly_a211.csv with 3 samples
# Processing file anomaly_a212.csv with 3 samples
# Processing file anomaly_a213.csv with 5 samples
# Processing file anomaly_a214.csv with 3 samples
# Processing file anomaly_a215.csv with 5 samples
# Processing file anomaly_a216.csv with 2 samples
# Processing file anomaly_a217.csv with 3 samples
# Processing file anomaly_a218.csv with 2 samples
# Processing file anomaly_a219.csv with 2 samples
# Processing file anomaly_a22.csv with 3 samples
# Processing file anomaly_a220.csv with 5 samples
# Processing file anomaly_a221.csv with 4 samples
# Processing file anomaly_a222.csv with 5 samples
# Processing file anomaly_a223.csv with 3 samples
# Processing file anomaly_a224.csv with 3 samples
# Processing file anomaly_a225.csv with 4 samples
# Processing file anomaly_a226.csv with 3 samples
# Processing file anomaly_a227.csv with 3 samples
# Processing file anomaly_a228.csv with 4 samples
# Processing file anomaly_a229.csv with 5 samples
# Processing file anomaly_a23.csv with 4 samples
# Processing file anomaly_a230.csv with 2 samples
# Processing file anomaly_a231.csv with 4 samples
# Processing file anomaly_a232.csv with 2 samples
# Processing file anomaly_a233.csv with 3 samples
# Processing file anomaly_a234.csv with 3 samples
# Skipping file anomaly_a235.csv - too few frames (4 < 5)
# Skipping file anomaly_a236.csv - too few frames (4 < 5)
# Processing file anomaly_a237.csv with 4 samples
# Processing file anomaly_a238.csv with 4 samples
# Processing file anomaly_a239.csv with 4 samples
# Processing file anomaly_a24.csv with 5 samples
# Processing file anomaly_a240.csv with 3 samples
# Processing file anomaly_a241.csv with 4 samples
# Processing file anomaly_a242.csv with 4 samples
# Processing file anomaly_a243.csv with 3 samples
# Processing file anomaly_a244.csv with 3 samples
# Processing file anomaly_a245.csv with 4 samples
# Processing file anomaly_a246.csv with 3 samples
# Processing file anomaly_a247.csv with 3 samples
# Processing file anomaly_a248.csv with 5 samples
# Processing file anomaly_a249.csv with 3 samples
# Processing file anomaly_a25.csv with 4 samples
# Processing file anomaly_a250.csv with 4 samples
# Processing file anomaly_a251.csv with 1 samples
# Processing file anomaly_a252.csv with 3 samples
# Processing file anomaly_a253.csv with 3 samples
# Processing file anomaly_a254.csv with 2 samples
# Processing file anomaly_a255.csv with 3 samples
# Processing file anomaly_a256.csv with 4 samples
# Skipping file anomaly_a257.csv - too few frames (4 < 5)
# Processing file anomaly_a258.csv with 4 samples
# Processing file anomaly_a259.csv with 3 samples
# Processing file anomaly_a26.csv with 4 samples
# Skipping file anomaly_a260.csv - too few frames (3 < 5)
# Processing file anomaly_a261.csv with 4 samples
# Processing file anomaly_a262.csv with 3 samples
# Processing file anomaly_a263.csv with 3 samples
# Processing file anomaly_a264.csv with 5 samples
# Processing file anomaly_a265.csv with 5 samples
# Skipping file anomaly_a266.csv - too few frames (4 < 5)
# Processing file anomaly_a267.csv with 3 samples
# Processing file anomaly_a268.csv with 3 samples
# Processing file anomaly_a269.csv with 3 samples
# Processing file anomaly_a27.csv with 3 samples
# Processing file anomaly_a270.csv with 3 samples
# Processing file anomaly_a271.csv with 4 samples
# Processing file anomaly_a272.csv with 4 samples
# Processing file anomaly_a273.csv with 2 samples
# Processing file anomaly_a274.csv with 3 samples
# Processing file anomaly_a275.csv with 3 samples
# Processing file anomaly_a276.csv with 4 samples
# Processing file anomaly_a277.csv with 5 samples
# Processing file anomaly_a278.csv with 3 samples
# Processing file anomaly_a279.csv with 4 samples
# Processing file anomaly_a28.csv with 2 samples
# Processing file anomaly_a280.csv with 4 samples
# Processing file anomaly_a281.csv with 4 samples
# Processing file anomaly_a282.csv with 4 samples
# Processing file anomaly_a283.csv with 3 samples
# Processing file anomaly_a284.csv with 3 samples
# Processing file anomaly_a285.csv with 4 samples
# Processing file anomaly_a286.csv with 3 samples
# Processing file anomaly_a287.csv with 4 samples
# Processing file anomaly_a288.csv with 3 samples
# Processing file anomaly_a289.csv with 2 samples
# Processing file anomaly_a29.csv with 5 samples
# Processing file anomaly_a290.csv with 2 samples
# Processing file anomaly_a291.csv with 3 samples
# Processing file anomaly_a292.csv with 3 samples
# Processing file anomaly_a293.csv with 2 samples
# Skipping file anomaly_a294.csv - too few frames (2 < 5)
# Processing file anomaly_a295.csv with 3 samples
# Processing file anomaly_a296.csv with 3 samples
# Processing file anomaly_a297.csv with 4 samples
# Skipping file anomaly_a298.csv - too few frames (4 < 5)
# Processing file anomaly_a299.csv with 2 samples
# Processing file anomaly_a3.csv with 3 samples
# Processing file anomaly_a30.csv with 3 samples
# Processing file anomaly_a300.csv with 4 samples
# Processing file anomaly_a301.csv with 3 samples
# Processing file anomaly_a302.csv with 3 samples
# Processing file anomaly_a303.csv with 3 samples
# Processing file anomaly_a304.csv with 4 samples
# Processing file anomaly_a305.csv with 3 samples
# Processing file anomaly_a306.csv with 3 samples
# Processing file anomaly_a307.csv with 3 samples
# Processing file anomaly_a308.csv with 1 samples
# Skipping file anomaly_a309.csv - too few frames (4 < 5)
# Processing file anomaly_a31.csv with 3 samples
# Processing file anomaly_a310.csv with 3 samples
# Processing file anomaly_a311.csv with 2 samples
# Processing file anomaly_a312.csv with 4 samples
# Processing file anomaly_a313.csv with 4 samples
# Processing file anomaly_a314.csv with 1 samples
# Processing file anomaly_a315.csv with 4 samples
# Processing file anomaly_a316.csv with 3 samples
# Processing file anomaly_a317.csv with 3 samples
# Processing file anomaly_a318.csv with 4 samples
# Skipping file anomaly_a319.csv - too few frames (4 < 5)
# Processing file anomaly_a32.csv with 5 samples
# Skipping file anomaly_a320.csv - too few frames (4 < 5)
# Processing file anomaly_a321.csv with 1 samples
# Processing file anomaly_a322.csv with 2 samples
# Skipping file anomaly_a323.csv - too few frames (4 < 5)
# Processing file anomaly_a324.csv with 3 samples
# Processing file anomaly_a325.csv with 5 samples
# Processing file anomaly_a326.csv with 3 samples
# Processing file anomaly_a327.csv with 2 samples
# Processing file anomaly_a328.csv with 3 samples
# Processing file anomaly_a329.csv with 3 samples
# Processing file anomaly_a33.csv with 5 samples
# Processing file anomaly_a330.csv with 3 samples
# Skipping file anomaly_a331.csv - too few frames (4 < 5)
# Processing file anomaly_a332.csv with 3 samples
# Processing file anomaly_a333.csv with 3 samples
# Processing file anomaly_a334.csv with 2 samples
# Processing file anomaly_a335.csv with 3 samples
# Processing file anomaly_a336.csv with 1 samples
# Processing file anomaly_a337.csv with 2 samples
# Processing file anomaly_a338.csv with 3 samples
# Processing file anomaly_a339.csv with 4 samples
# Processing file anomaly_a34.csv with 3 samples
# Processing file anomaly_a340.csv with 3 samples
# Processing file anomaly_a341.csv with 3 samples
# Processing file anomaly_a342.csv with 3 samples
# Processing file anomaly_a343.csv with 3 samples
# Processing file anomaly_a344.csv with 4 samples
# Processing file anomaly_a345.csv with 4 samples
# Processing file anomaly_a346.csv with 3 samples
# Processing file anomaly_a347.csv with 3 samples
# Processing file anomaly_a348.csv with 3 samples
# Processing file anomaly_a349.csv with 4 samples
# Processing file anomaly_a35.csv with 4 samples
# Processing file anomaly_a350.csv with 3 samples
# Processing file anomaly_a351.csv with 3 samples
# Processing file anomaly_a352.csv with 4 samples
# Processing file anomaly_a353.csv with 3 samples
# Processing file anomaly_a354.csv with 5 samples
# Processing file anomaly_a355.csv with 4 samples
# Processing file anomaly_a356.csv with 5 samples
# Processing file anomaly_a357.csv with 4 samples
# Processing file anomaly_a358.csv with 3 samples
# Skipping file anomaly_a359.csv - too few frames (2 < 5)
# Processing file anomaly_a36.csv with 1 samples
# Processing file anomaly_a360.csv with 3 samples
# Processing file anomaly_a361.csv with 3 samples
# Processing file anomaly_a362.csv with 3 samples
# Processing file anomaly_a363.csv with 3 samples
# Processing file anomaly_a364.csv with 3 samples
# Processing file anomaly_a365.csv with 3 samples
# Processing file anomaly_a366.csv with 4 samples
# Processing file anomaly_a367.csv with 3 samples
# Processing file anomaly_a368.csv with 4 samples
# Processing file anomaly_a369.csv with 4 samples
# Processing file anomaly_a37.csv with 3 samples
# Processing file anomaly_a370.csv with 3 samples
# Skipping file anomaly_a371.csv - too few frames (4 < 5)
# Processing file anomaly_a372.csv with 4 samples
# Processing file anomaly_a373.csv with 3 samples
# Processing file anomaly_a374.csv with 3 samples
# Processing file anomaly_a375.csv with 4 samples
# Processing file anomaly_a376.csv with 4 samples
# Processing file anomaly_a377.csv with 2 samples
# Processing file anomaly_a378.csv with 5 samples
# Processing file anomaly_a379.csv with 1 samples
# Processing file anomaly_a38.csv with 3 samples
# Processing file anomaly_a380.csv with 3 samples
# Processing file anomaly_a381.csv with 3 samples
# Processing file anomaly_a382.csv with 4 samples
# Processing file anomaly_a383.csv with 2 samples
# Processing file anomaly_a384.csv with 5 samples
# Processing file anomaly_a385.csv with 5 samples
# Processing file anomaly_a386.csv with 6 samples
# Processing file anomaly_a387.csv with 3 samples
# Processing file anomaly_a388.csv with 2 samples
# Processing file anomaly_a389.csv with 3 samples
# Processing file anomaly_a39.csv with 2 samples
# Processing file anomaly_a390.csv with 2 samples
# Processing file anomaly_a391.csv with 3 samples
# Processing file anomaly_a392.csv with 3 samples
# Processing file anomaly_a393.csv with 3 samples
# Processing file anomaly_a394.csv with 4 samples
# Processing file anomaly_a395.csv with 3 samples
# Processing file anomaly_a396.csv with 2 samples
# Processing file anomaly_a397.csv with 5 samples
# Processing file anomaly_a398.csv with 2 samples
# Processing file anomaly_a399.csv with 3 samples
# Processing file anomaly_a4.csv with 3 samples
# Processing file anomaly_a40.csv with 3 samples
# Processing file anomaly_a400.csv with 3 samples
# Processing file anomaly_a401.csv with 3 samples
# Processing file anomaly_a402.csv with 5 samples
# Processing file anomaly_a403.csv with 3 samples
# Processing file anomaly_a404.csv with 374 samples
# Processing file anomaly_a405.csv with 3 samples
# Processing file anomaly_a406.csv with 2 samples
# Processing file anomaly_a407.csv with 3 samples
# Processing file anomaly_a408.csv with 3 samples
# Processing file anomaly_a409.csv with 3 samples
# Processing file anomaly_a41.csv with 5 samples
# Processing file anomaly_a410.csv with 3 samples
# Processing file anomaly_a411.csv with 3 samples
# Skipping file anomaly_a412.csv - too few frames (2 < 5)
# Processing file anomaly_a413.csv with 4 samples
# Processing file anomaly_a414.csv with 3 samples
# Processing file anomaly_a415.csv with 3 samples
# Processing file anomaly_a416.csv with 3 samples
# Processing file anomaly_a417.csv with 4 samples
# Processing file anomaly_a418.csv with 5 samples
# Processing file anomaly_a419.csv with 3 samples
# Processing file anomaly_a42.csv with 4 samples
# Processing file anomaly_a420.csv with 3 samples
# Processing file anomaly_a421.csv with 4 samples
# Processing file anomaly_a422.csv with 4 samples
# Processing file anomaly_a423.csv with 4 samples
# Processing file anomaly_a424.csv with 3 samples
# Processing file anomaly_a425.csv with 3 samples
# Processing file anomaly_a426.csv with 1 samples
# Processing file anomaly_a427.csv with 2 samples
# Processing file anomaly_a428.csv with 2 samples
# Processing file anomaly_a429.csv with 3 samples
# Processing file anomaly_a43.csv with 3 samples
# Processing file anomaly_a430.csv with 4 samples
# Processing file anomaly_a431.csv with 2 samples
# Processing file anomaly_a432.csv with 3 samples
# Processing file anomaly_a433.csv with 3 samples
# Skipping file anomaly_a434.csv - too few frames (4 < 5)
# Processing file anomaly_a435.csv with 4 samples
# Processing file anomaly_a436.csv with 3 samples
# Skipping file anomaly_a437.csv - too few frames (4 < 5)
# Processing file anomaly_a438.csv with 2 samples
# Processing file anomaly_a439.csv with 3 samples
# Processing file anomaly_a44.csv with 5 samples
# Processing file anomaly_a440.csv with 3 samples
# Processing file anomaly_a441.csv with 5 samples
# Processing file anomaly_a442.csv with 4 samples
# Processing file anomaly_a443.csv with 3 samples
# Processing file anomaly_a444.csv with 3 samples
# Processing file anomaly_a445.csv with 5 samples
# Processing file anomaly_a446.csv with 3 samples
# Processing file anomaly_a447.csv with 3 samples
# Processing file anomaly_a448.csv with 3 samples
# Processing file anomaly_a449.csv with 4 samples
# Skipping file anomaly_a45.csv - too few frames (4 < 5)
# Processing file anomaly_a450.csv with 3 samples
# Skipping file anomaly_a451.csv - too few frames (4 < 5)
# Processing file anomaly_a452.csv with 5 samples
# Processing file anomaly_a453.csv with 4 samples
# Processing file anomaly_a454.csv with 4 samples
# Skipping file anomaly_a455.csv - too few frames (3 < 5)
# Processing file anomaly_a456.csv with 3 samples
# Processing file anomaly_a457.csv with 1 samples
# Processing file anomaly_a458.csv with 2 samples
# Processing file anomaly_a459.csv with 5 samples
# Processing file anomaly_a46.csv with 4 samples
# Skipping file anomaly_a460.csv - too few frames (4 < 5)
# Processing file anomaly_a461.csv with 3 samples
# Processing file anomaly_a462.csv with 4 samples
# Processing file anomaly_a463.csv with 4 samples
# Processing file anomaly_a464.csv with 3 samples
# Processing file anomaly_a465.csv with 4 samples
# Skipping file anomaly_a466.csv - too few frames (4 < 5)
# Processing file anomaly_a467.csv with 3 samples
# Processing file anomaly_a468.csv with 3 samples
# Processing file anomaly_a469.csv with 5 samples
# Processing file anomaly_a47.csv with 1 samples
# Processing file anomaly_a470.csv with 2 samples
# Processing file anomaly_a471.csv with 4 samples
# Skipping file anomaly_a472.csv - too few frames (4 < 5)
# Processing file anomaly_a473.csv with 4 samples
# Processing file anomaly_a474.csv with 3 samples
# Processing file anomaly_a475.csv with 2 samples
# Processing file anomaly_a476.csv with 3 samples
# Processing file anomaly_a477.csv with 4 samples
# Processing file anomaly_a478.csv with 3 samples
# Processing file anomaly_a479.csv with 5 samples
# Processing file anomaly_a48.csv with 3 samples
# Processing file anomaly_a480.csv with 3 samples
# Processing file anomaly_a481.csv with 4 samples
# Processing file anomaly_a482.csv with 1 samples
# Skipping file anomaly_a483.csv - too few frames (3 < 5)
# Processing file anomaly_a484.csv with 4 samples
# Processing file anomaly_a485.csv with 5 samples
# Processing file anomaly_a486.csv with 3 samples
# Processing file anomaly_a487.csv with 3 samples
# Processing file anomaly_a488.csv with 3 samples
# Processing file anomaly_a489.csv with 4 samples
# Processing file anomaly_a49.csv with 3 samples
# Processing file anomaly_a490.csv with 2 samples
# Processing file anomaly_a491.csv with 5 samples
# Processing file anomaly_a492.csv with 4 samples
# Processing file anomaly_a493.csv with 2 samples
# Processing file anomaly_a494.csv with 4 samples
# Processing file anomaly_a495.csv with 3 samples
# Processing file anomaly_a496.csv with 3 samples
# Processing file anomaly_a497.csv with 4 samples
# Processing file anomaly_a498.csv with 2 samples
# Processing file anomaly_a499.csv with 2 samples
# Processing file anomaly_a5.csv with 3 samples
# Processing file anomaly_a50.csv with 3 samples
# Processing file anomaly_a500.csv with 3 samples
# Processing file anomaly_a501.csv with 4 samples
# Processing file anomaly_a502.csv with 2 samples
# Processing file anomaly_a503.csv with 3 samples
# Processing file anomaly_a504.csv with 3 samples
# Skipping file anomaly_a505.csv - too few frames (4 < 5)
# Processing file anomaly_a506.csv with 5 samples
# Processing file anomaly_a507.csv with 2 samples
# Processing file anomaly_a508.csv with 3 samples
# Processing file anomaly_a509.csv with 2 samples
# Processing file anomaly_a51.csv with 3 samples
# Skipping file anomaly_a510.csv - too few frames (2 < 5)
# Processing file anomaly_a511.csv with 4 samples
# Processing file anomaly_a512.csv with 4 samples
# Processing file anomaly_a513.csv with 2 samples
# Processing file anomaly_a514.csv with 3 samples
# Processing file anomaly_a515.csv with 3 samples
# Processing file anomaly_a516.csv with 5 samples
# Processing file anomaly_a517.csv with 3 samples
# Skipping file anomaly_a518.csv - too few frames (4 < 5)
# Processing file anomaly_a519.csv with 2 samples
# Processing file anomaly_a52.csv with 1 samples
# Processing file anomaly_a520.csv with 2 samples
# Processing file anomaly_a521.csv with 3 samples
# Processing file anomaly_a522.csv with 5 samples
# Processing file anomaly_a523.csv with 3 samples
# Processing file anomaly_a524.csv with 4 samples
# Processing file anomaly_a525.csv with 5 samples
# Processing file anomaly_a526.csv with 3 samples
# Processing file anomaly_a527.csv with 3 samples
# Processing file anomaly_a528.csv with 5 samples
# Processing file anomaly_a529.csv with 3 samples
# Processing file anomaly_a53.csv with 3 samples
# Processing file anomaly_a530.csv with 3 samples
# Processing file anomaly_a531.csv with 3 samples
# Processing file anomaly_a532.csv with 3 samples
# Processing file anomaly_a533.csv with 3 samples
# Processing file anomaly_a534.csv with 3 samples
# Processing file anomaly_a535.csv with 2 samples
# Processing file anomaly_a536.csv with 3 samples
# Processing file anomaly_a537.csv with 4 samples
# Processing file anomaly_a538.csv with 5 samples
# Processing file anomaly_a539.csv with 2 samples
# Processing file anomaly_a54.csv with 3 samples
# Processing file anomaly_a540.csv with 4 samples
# Processing file anomaly_a541.csv with 3 samples
# Processing file anomaly_a542.csv with 4 samples
# Processing file anomaly_a543.csv with 3 samples
# Processing file anomaly_a544.csv with 1 samples
# Processing file anomaly_a545.csv with 4 samples
# Processing file anomaly_a546.csv with 4 samples
# Processing file anomaly_a547.csv with 3 samples
# Processing file anomaly_a548.csv with 3 samples
# Processing file anomaly_a549.csv with 5 samples
# Processing file anomaly_a55.csv with 4 samples
# Processing file anomaly_a550.csv with 4 samples
# Processing file anomaly_a551.csv with 4 samples
# Processing file anomaly_a552.csv with 2 samples
# Processing file anomaly_a553.csv with 3 samples
# Processing file anomaly_a554.csv with 4 samples
# Processing file anomaly_a555.csv with 3 samples
# Processing file anomaly_a556.csv with 4 samples
# Skipping file anomaly_a557.csv - too few frames (4 < 5)
# Processing file anomaly_a558.csv with 4 samples
# Processing file anomaly_a559.csv with 3 samples
# Processing file anomaly_a56.csv with 3 samples
# Processing file anomaly_a560.csv with 5 samples
# Processing file anomaly_a561.csv with 3 samples
# Processing file anomaly_a562.csv with 2 samples
# Processing file anomaly_a563.csv with 3 samples
# Skipping file anomaly_a564.csv - too few frames (4 < 5)
# Skipping file anomaly_a565.csv - too few frames (4 < 5)
# Processing file anomaly_a566.csv with 3 samples
# Processing file anomaly_a567.csv with 3 samples
# Processing file anomaly_a568.csv with 1 samples
# Processing file anomaly_a569.csv with 4 samples
# Processing file anomaly_a57.csv with 3 samples
# Processing file anomaly_a570.csv with 3 samples
# Processing file anomaly_a571.csv with 3 samples
# Processing file anomaly_a572.csv with 3 samples
# Processing file anomaly_a573.csv with 3 samples
# Processing file anomaly_a574.csv with 5 samples
# Processing file anomaly_a575.csv with 3 samples
# Processing file anomaly_a576.csv with 3 samples
# Skipping file anomaly_a577.csv - too few frames (2 < 5)
# Processing file anomaly_a578.csv with 4 samples
# Processing file anomaly_a579.csv with 2 samples
# Processing file anomaly_a58.csv with 3 samples
# Processing file anomaly_a580.csv with 4 samples
# Processing file anomaly_a581.csv with 2 samples
# Processing file anomaly_a582.csv with 3 samples
# Processing file anomaly_a583.csv with 5 samples
# Skipping file anomaly_a584.csv - too few frames (4 < 5)
# Processing file anomaly_a585.csv with 3 samples
# Processing file anomaly_a586.csv with 3 samples
# Skipping file anomaly_a587.csv - too few frames (4 < 5)
# Processing file anomaly_a588.csv with 2 samples
# Processing file anomaly_a589.csv with 1 samples
# Processing file anomaly_a59.csv with 4 samples
# Processing file anomaly_a590.csv with 4 samples
# Processing file anomaly_a591.csv with 3 samples
# Skipping file anomaly_a592.csv - too few frames (4 < 5)
# Processing file anomaly_a593.csv with 1 samples
# Processing file anomaly_a594.csv with 3 samples
# Processing file anomaly_a595.csv with 3 samples
# Processing file anomaly_a596.csv with 3 samples
# Skipping file anomaly_a597.csv - too few frames (4 < 5)
# Processing file anomaly_a598.csv with 1 samples
# Processing file anomaly_a599.csv with 2 samples
# Processing file anomaly_a6.csv with 3 samples
# Processing file anomaly_a60.csv with 3 samples
# Processing file anomaly_a600.csv with 3 samples
# Processing file anomaly_a601.csv with 5 samples
# Processing file anomaly_a602.csv with 3 samples
# Processing file anomaly_a603.csv with 2 samples
# Processing file anomaly_a604.csv with 3 samples
# Processing file anomaly_a605.csv with 3 samples
# Processing file anomaly_a606.csv with 3 samples
# Processing file anomaly_a607.csv with 4 samples
# Processing file anomaly_a608.csv with 3 samples
# Skipping file anomaly_a609.csv - too few frames (4 < 5)
# Processing file anomaly_a61.csv with 3 samples
# Processing file anomaly_a610.csv with 3 samples
# Processing file anomaly_a611.csv with 2 samples
# Processing file anomaly_a612.csv with 4 samples
# Processing file anomaly_a613.csv with 3 samples
# Processing file anomaly_a614.csv with 2 samples
# Processing file anomaly_a615.csv with 4 samples
# Processing file anomaly_a616.csv with 4 samples
# Processing file anomaly_a617.csv with 4 samples
# Skipping file anomaly_a618.csv - too few frames (4 < 5)
# Skipping file anomaly_a619.csv - too few frames (4 < 5)
# Processing file anomaly_a62.csv with 3 samples
# Processing file anomaly_a620.csv with 4 samples
# Processing file anomaly_a621.csv with 1 samples
# Processing file anomaly_a622.csv with 3 samples
# Processing file anomaly_a623.csv with 4 samples
# Processing file anomaly_a624.csv with 3 samples
# Processing file anomaly_a625.csv with 4 samples
# Processing file anomaly_a626.csv with 4 samples
# Skipping file anomaly_a627.csv - too few frames (4 < 5)
# Processing file anomaly_a628.csv with 3 samples
# Processing file anomaly_a629.csv with 3 samples
# Processing file anomaly_a63.csv with 3 samples
# Processing file anomaly_a630.csv with 5 samples
# Processing file anomaly_a631.csv with 3 samples
# Processing file anomaly_a632.csv with 3 samples
# Processing file anomaly_a633.csv with 4 samples
# Processing file anomaly_a634.csv with 3 samples
# Processing file anomaly_a635.csv with 3 samples
# Skipping file anomaly_a636.csv - too few frames (4 < 5)
# Processing file anomaly_a637.csv with 5 samples
# Processing file anomaly_a638.csv with 2 samples
# Processing file anomaly_a639.csv with 2 samples
# Processing file anomaly_a64.csv with 5 samples
# Skipping file anomaly_a640.csv - too few frames (4 < 5)
# Processing file anomaly_a641.csv with 3 samples
# Processing file anomaly_a642.csv with 3 samples
# Processing file anomaly_a643.csv with 3 samples
# Processing file anomaly_a644.csv with 4 samples
# Processing file anomaly_a645.csv with 3 samples
# Processing file anomaly_a646.csv with 3 samples
# Processing file anomaly_a647.csv with 3 samples
# Skipping file anomaly_a648.csv - too few frames (4 < 5)
# Processing file anomaly_a649.csv with 3 samples
# Processing file anomaly_a65.csv with 5 samples
# Processing file anomaly_a650.csv with 5 samples
# Processing file anomaly_a651.csv with 4 samples
# Processing file anomaly_a652.csv with 4 samples
# Processing file anomaly_a653.csv with 4 samples
# Processing file anomaly_a654.csv with 4 samples
# Processing file anomaly_a655.csv with 3 samples
# Skipping file anomaly_a656.csv - too few frames (4 < 5)
# Processing file anomaly_a657.csv with 3 samples
# Processing file anomaly_a658.csv with 3 samples
# Processing file anomaly_a659.csv with 4 samples
# Processing file anomaly_a66.csv with 3 samples
# Processing file anomaly_a660.csv with 3 samples
# Processing file anomaly_a661.csv with 2 samples
# Processing file anomaly_a662.csv with 5 samples
# Processing file anomaly_a663.csv with 2 samples
# Processing file anomaly_a664.csv with 3 samples
# Skipping file anomaly_a665.csv - too few frames (4 < 5)
# Skipping file anomaly_a666.csv - too few frames (2 < 5)
# Processing file anomaly_a667.csv with 3 samples
# Processing file anomaly_a668.csv with 5 samples
# Processing file anomaly_a669.csv with 1 samples
# Processing file anomaly_a67.csv with 4 samples
# Processing file anomaly_a670.csv with 3 samples
# Processing file anomaly_a671.csv with 3 samples
# Processing file anomaly_a672.csv with 3 samples
# Processing file anomaly_a673.csv with 2 samples
# Processing file anomaly_a674.csv with 3 samples
# Processing file anomaly_a675.csv with 3 samples
# Processing file anomaly_a676.csv with 3 samples
# Processing file anomaly_a677.csv with 1 samples
# Processing file anomaly_a678.csv with 3 samples
# Processing file anomaly_a679.csv with 3 samples
# Processing file anomaly_a68.csv with 4 samples
# Processing file anomaly_a680.csv with 4 samples
# Processing file anomaly_a681.csv with 3 samples
# Skipping file anomaly_a682.csv - too few frames (4 < 5)
# Processing file anomaly_a683.csv with 3 samples
# Processing file anomaly_a684.csv with 3 samples
# Processing file anomaly_a685.csv with 8 samples
# Processing file anomaly_a686.csv with 2 samples
# Processing file anomaly_a687.csv with 5 samples
# Processing file anomaly_a688.csv with 6 samples
# Processing file anomaly_a689.csv with 3 samples
# Skipping file anomaly_a69.csv - too few frames (4 < 5)
# Processing file anomaly_a690.csv with 5 samples
# Processing file anomaly_a691.csv with 3 samples
# Processing file anomaly_a692.csv with 5 samples
# Processing file anomaly_a693.csv with 4 samples
# Processing file anomaly_a694.csv with 5 samples
# Processing file anomaly_a695.csv with 2 samples
# Processing file anomaly_a696.csv with 1 samples
# Processing file anomaly_a697.csv with 4 samples
# Processing file anomaly_a698.csv with 4 samples
# Processing file anomaly_a699.csv with 3 samples
# Processing file anomaly_a7.csv with 3 samples
# Processing file anomaly_a70.csv with 3 samples
# Processing file anomaly_a700.csv with 5 samples
# Processing file anomaly_a701.csv with 3 samples
# Processing file anomaly_a702.csv with 3 samples
# Processing file anomaly_a703.csv with 4 samples
# Processing file anomaly_a704.csv with 4 samples
# Processing file anomaly_a705.csv with 3 samples
# Processing file anomaly_a706.csv with 4 samples
# Processing file anomaly_a707.csv with 3 samples
# Processing file anomaly_a708.csv with 4 samples
# Processing file anomaly_a709.csv with 3 samples
# Processing file anomaly_a71.csv with 3 samples
# Processing file anomaly_a710.csv with 4 samples
# Processing file anomaly_a711.csv with 3 samples
# Skipping file anomaly_a712.csv - too few frames (2 < 5)
# Processing file anomaly_a713.csv with 5 samples
# Processing file anomaly_a714.csv with 2 samples
# Processing file anomaly_a715.csv with 2 samples
# Processing file anomaly_a716.csv with 2 samples
# Processing file anomaly_a717.csv with 2 samples
# Processing file anomaly_a718.csv with 3 samples
# Processing file anomaly_a719.csv with 3 samples
# Processing file anomaly_a72.csv with 4 samples
# Processing file anomaly_a720.csv with 1 samples
# Processing file anomaly_a721.csv with 3 samples
# Processing file anomaly_a722.csv with 3 samples
# Processing file anomaly_a723.csv with 2 samples
# Processing file anomaly_a724.csv with 2 samples
# Processing file anomaly_a725.csv with 3 samples
# Processing file anomaly_a726.csv with 3 samples
# Processing file anomaly_a727.csv with 5 samples
# Processing file anomaly_a728.csv with 3 samples
# Processing file anomaly_a729.csv with 4 samples
# Skipping file anomaly_a73.csv - too few frames (3 < 5)
# Processing file anomaly_a730.csv with 3 samples
# Processing file anomaly_a731.csv with 3 samples
# Processing file anomaly_a732.csv with 3 samples
# Processing file anomaly_a733.csv with 3 samples
# Processing file anomaly_a734.csv with 3 samples
# Processing file anomaly_a735.csv with 3 samples
# Processing file anomaly_a736.csv with 3 samples
# Processing file anomaly_a737.csv with 4 samples
# Skipping file anomaly_a738.csv - too few frames (4 < 5)
# Processing file anomaly_a739.csv with 2 samples
# Processing file anomaly_a74.csv with 3 samples
# Processing file anomaly_a740.csv with 5 samples
# Processing file anomaly_a741.csv with 3 samples
# Processing file anomaly_a742.csv with 3 samples
# Processing file anomaly_a743.csv with 3 samples
# Processing file anomaly_a744.csv with 4 samples
# Processing file anomaly_a745.csv with 3 samples
# Processing file anomaly_a746.csv with 2 samples
# Processing file anomaly_a747.csv with 3 samples
# Processing file anomaly_a748.csv with 3 samples
# Processing file anomaly_a749.csv with 5 samples
# Processing file anomaly_a75.csv with 3 samples
# Processing file anomaly_a750.csv with 3 samples
# Processing file anomaly_a751.csv with 3 samples
# Processing file anomaly_a752.csv with 1 samples
# Processing file anomaly_a753.csv with 2 samples
# Skipping file anomaly_a754.csv - too few frames (2 < 5)
# Processing file anomaly_a755.csv with 3 samples
# Processing file anomaly_a756.csv with 4 samples
# Processing file anomaly_a757.csv with 3 samples
# Processing file anomaly_a758.csv with 4 samples
# Processing file anomaly_a759.csv with 5 samples
# Processing file anomaly_a76.csv with 3 samples
# Processing file anomaly_a760.csv with 2 samples
# Processing file anomaly_a761.csv with 1 samples
# Processing file anomaly_a762.csv with 4 samples
# Skipping file anomaly_a763.csv - too few frames (4 < 5)
# Processing file anomaly_a764.csv with 4 samples
# Processing file anomaly_a765.csv with 2 samples
# Processing file anomaly_a766.csv with 4 samples
# Processing file anomaly_a767.csv with 3 samples
# Processing file anomaly_a768.csv with 3 samples
# Processing file anomaly_a769.csv with 3 samples
# Processing file anomaly_a77.csv with 5 samples
# Skipping file anomaly_a770.csv - too few frames (4 < 5)
# Processing file anomaly_a771.csv with 4 samples
# Processing file anomaly_a772.csv with 3 samples
# Skipping file anomaly_a773.csv - too few frames (3 < 5)
# Processing file anomaly_a774.csv with 2 samples
# Processing file anomaly_a775.csv with 3 samples
# Processing file anomaly_a776.csv with 2 samples
# Processing file anomaly_a777.csv with 3 samples
# Processing file anomaly_a778.csv with 3 samples
# Processing file anomaly_a779.csv with 3 samples
# Processing file anomaly_a78.csv with 4 samples
# Processing file anomaly_a780.csv with 2 samples
# Processing file anomaly_a781.csv with 5 samples
# Processing file anomaly_a782.csv with 2 samples
# Processing file anomaly_a783.csv with 2 samples
# Processing file anomaly_a784.csv with 4 samples
# Skipping file anomaly_a785.csv - too few frames (4 < 5)
# Processing file anomaly_a786.csv with 3 samples
# Processing file anomaly_a787.csv with 2 samples
# Processing file anomaly_a788.csv with 3 samples
# Skipping file anomaly_a789.csv - too few frames (4 < 5)
# Processing file anomaly_a79.csv with 2 samples
# Processing file anomaly_a790.csv with 2 samples
# Processing file anomaly_a791.csv with 4 samples
# Processing file anomaly_a792.csv with 5 samples
# Processing file anomaly_a793.csv with 3 samples
# Processing file anomaly_a794.csv with 3 samples
# Processing file anomaly_a795.csv with 4 samples
# Skipping file anomaly_a796.csv - too few frames (4 < 5)
# Processing file anomaly_a797.csv with 3 samples
# Processing file anomaly_a798.csv with 5 samples
# Processing file anomaly_a799.csv with 3 samples
# Processing file anomaly_a8.csv with 1 samples
# Processing file anomaly_a80.csv with 4 samples
# Processing file anomaly_a800.csv with 5 samples
# Processing file anomaly_a801.csv with 3 samples
# Processing file anomaly_a802.csv with 2 samples
# Processing file anomaly_a803.csv with 3 samples
# Processing file anomaly_a804.csv with 3 samples
# Processing file anomaly_a805.csv with 4 samples
# Processing file anomaly_a806.csv with 3 samples
# Skipping file anomaly_a807.csv - too few frames (4 < 5)
# Processing file anomaly_a808.csv with 2 samples
# Processing file anomaly_a809.csv with 3 samples
# Processing file anomaly_a81.csv with 2 samples
# Processing file anomaly_a810.csv with 3 samples
# Processing file anomaly_a811.csv with 2 samples
# Processing file anomaly_a812.csv with 3 samples
# Processing file anomaly_a813.csv with 2 samples
# Processing file anomaly_a814.csv with 4 samples
# Processing file anomaly_a815.csv with 3 samples
# Processing file anomaly_a816.csv with 3 samples
# Processing file anomaly_a817.csv with 3 samples
# Processing file anomaly_a818.csv with 3 samples
# Processing file anomaly_a819.csv with 4 samples
# Processing file anomaly_a82.csv with 4 samples
# Skipping file anomaly_a820.csv - too few frames (4 < 5)
# Processing file anomaly_a821.csv with 4 samples
# Processing file anomaly_a822.csv with 4 samples
# Processing file anomaly_a823.csv with 4 samples
# Processing file anomaly_a824.csv with 2 samples
# Processing file anomaly_a825.csv with 4 samples
# Processing file anomaly_a826.csv with 4 samples
# Processing file anomaly_a827.csv with 5 samples
# Processing file anomaly_a828.csv with 4 samples
# Processing file anomaly_a829.csv with 3 samples
# Processing file anomaly_a83.csv with 3 samples
# Processing file anomaly_a830.csv with 1 samples
# Skipping file anomaly_a831.csv - too few frames (4 < 5)
# Skipping file anomaly_a832.csv - too few frames (4 < 5)
# Processing file anomaly_a833.csv with 3 samples
# Processing file anomaly_a834.csv with 4 samples
# Processing file anomaly_a835.csv with 1 samples
# Processing file anomaly_a836.csv with 3 samples
# Processing file anomaly_a837.csv with 1 samples
# Processing file anomaly_a838.csv with 4 samples
# Processing file anomaly_a839.csv with 3 samples
# Processing file anomaly_a84.csv with 3 samples
# Processing file anomaly_a840.csv with 5 samples
# Processing file anomaly_a841.csv with 5 samples
# Processing file anomaly_a842.csv with 3 samples
# Skipping file anomaly_a843.csv - too few frames (4 < 5)
# Skipping file anomaly_a844.csv - too few frames (4 < 5)
# Processing file anomaly_a845.csv with 2 samples
# Processing file anomaly_a846.csv with 5 samples
# Processing file anomaly_a847.csv with 3 samples
# Processing file anomaly_a848.csv with 3 samples
# Skipping file anomaly_a849.csv - too few frames (4 < 5)
# Processing file anomaly_a85.csv with 4 samples
# Processing file anomaly_a850.csv with 5 samples
# Processing file anomaly_a851.csv with 2 samples
# Processing file anomaly_a852.csv with 5 samples
# Skipping file anomaly_a853.csv - too few frames (4 < 5)
# Processing file anomaly_a854.csv with 3 samples
# Processing file anomaly_a855.csv with 3 samples
# Processing file anomaly_a856.csv with 4 samples
# Processing file anomaly_a857.csv with 5 samples
# Processing file anomaly_a858.csv with 1 samples
# Processing file anomaly_a859.csv with 5 samples
# Processing file anomaly_a86.csv with 2 samples
# Skipping file anomaly_a860.csv - too few frames (4 < 5)
# Processing file anomaly_a861.csv with 2 samples
# Processing file anomaly_a862.csv with 5 samples
# Processing file anomaly_a863.csv with 4 samples
# Processing file anomaly_a864.csv with 6 samples
# Processing file anomaly_a865.csv with 3 samples
# Processing file anomaly_a866.csv with 4 samples
# Processing file anomaly_a867.csv with 3 samples
# Processing file anomaly_a868.csv with 3 samples
# Processing file anomaly_a869.csv with 4 samples
# Skipping file anomaly_a87.csv - too few frames (4 < 5)
# Processing file anomaly_a870.csv with 3 samples
# Processing file anomaly_a871.csv with 2 samples
# Processing file anomaly_a872.csv with 5 samples
# Processing file anomaly_a873.csv with 3 samples
# Processing file anomaly_a874.csv with 3 samples
# Processing file anomaly_a875.csv with 3 samples
# Processing file anomaly_a876.csv with 3 samples
# Processing file anomaly_a877.csv with 3 samples
# Processing file anomaly_a878.csv with 2 samples
# Processing file anomaly_a879.csv with 2 samples
# Processing file anomaly_a88.csv with 3 samples
# Processing file anomaly_a880.csv with 4 samples
# Processing file anomaly_a881.csv with 3 samples
# Processing file anomaly_a882.csv with 3 samples
# Processing file anomaly_a883.csv with 3 samples
# Processing file anomaly_a884.csv with 2 samples
# Skipping file anomaly_a885.csv - too few frames (4 < 5)
# Skipping file anomaly_a886.csv - too few frames (4 < 5)
# Processing file anomaly_a887.csv with 3 samples
# Processing file anomaly_a888.csv with 3 samples
# Processing file anomaly_a889.csv with 2 samples
# Processing file anomaly_a89.csv with 4 samples
# Processing file anomaly_a890.csv with 5 samples
# Processing file anomaly_a891.csv with 2 samples
# Processing file anomaly_a892.csv with 3 samples
# Processing file anomaly_a893.csv with 2 samples
# Processing file anomaly_a894.csv with 3 samples
# Processing file anomaly_a895.csv with 3 samples
# Processing file anomaly_a896.csv with 3 samples
# Processing file anomaly_a897.csv with 3 samples
# Processing file anomaly_a898.csv with 2 samples
# Processing file anomaly_a899.csv with 5 samples
# Processing file anomaly_a9.csv with 3 samples
# Processing file anomaly_a90.csv with 2 samples
# Processing file anomaly_a900.csv with 4 samples
# Skipping file anomaly_a901.csv - too few frames (4 < 5)
# Processing file anomaly_a902.csv with 3 samples
# Processing file anomaly_a903.csv with 4 samples
# Processing file anomaly_a904.csv with 3 samples
# Processing file anomaly_a905.csv with 2 samples
# Processing file anomaly_a906.csv with 4 samples
# Processing file anomaly_a907.csv with 4 samples
# Processing file anomaly_a908.csv with 2 samples
# Processing file anomaly_a909.csv with 2 samples
# Processing file anomaly_a91.csv with 4 samples
# Skipping file anomaly_a910.csv - too few frames (4 < 5)
# Skipping file anomaly_a911.csv - too few frames (4 < 5)
# Processing file anomaly_a912.csv with 4 samples
# Processing file anomaly_a913.csv with 3 samples
# Processing file anomaly_a914.csv with 3 samples
# Processing file anomaly_a915.csv with 2 samples
# Processing file anomaly_a916.csv with 2 samples
# Processing file anomaly_a917.csv with 2 samples
# Processing file anomaly_a918.csv with 2 samples
# Processing file anomaly_a919.csv with 3 samples
# Processing file anomaly_a92.csv with 3 samples
# Processing file anomaly_a920.csv with 5 samples
# Processing file anomaly_a921.csv with 1 samples
# Processing file anomaly_a922.csv with 4 samples
# Processing file anomaly_a923.csv with 3 samples
# Processing file anomaly_a924.csv with 2 samples
# Processing file anomaly_a925.csv with 2 samples
# Processing file anomaly_a926.csv with 3 samples
# Processing file anomaly_a927.csv with 1 samples
# Processing file anomaly_a928.csv with 5 samples
# Processing file anomaly_a929.csv with 2 samples
# Processing file anomaly_a93.csv with 3 samples
# Processing file anomaly_a930.csv with 4 samples
# Processing file anomaly_a931.csv with 2 samples
# Processing file anomaly_a932.csv with 5 samples
# Processing file anomaly_a933.csv with 2 samples
# Processing file anomaly_a934.csv with 3 samples
# Processing file anomaly_a935.csv with 3 samples
# Processing file anomaly_a936.csv with 3 samples
# Processing file anomaly_a937.csv with 4 samples
# Processing file anomaly_a938.csv with 1 samples
# Processing file anomaly_a939.csv with 3 samples
# Processing file anomaly_a94.csv with 4 samples
# Processing file anomaly_a940.csv with 3 samples
# Processing file anomaly_a941.csv with 4 samples
# Processing file anomaly_a942.csv with 3 samples
# Processing file anomaly_a943.csv with 5 samples
# Processing file anomaly_a944.csv with 2 samples
# Processing file anomaly_a945.csv with 3 samples
# Processing file anomaly_a946.csv with 1 samples
# Processing file anomaly_a947.csv with 3 samples
# Processing file anomaly_a948.csv with 3 samples
# Processing file anomaly_a949.csv with 3 samples
# Processing file anomaly_a95.csv with 3 samples
# Processing file anomaly_a950.csv with 3 samples
# Processing file anomaly_a951.csv with 4 samples
# Processing file anomaly_a952.csv with 3 samples
# Processing file anomaly_a953.csv with 3 samples
# Processing file anomaly_a954.csv with 3 samples
# ...
# Skipping file nonanomaly_a911.csv - too few frames (4 < 5)
# Processing file nonanomaly_a912.csv with 2 samples
# Processing file nonanomaly_a913.csv with 3 samples
# Processing file nonanomaly_a914.csv with 3 samples
# Processing file nonanomaly_a915.csv with 3 samples
# Processing file nonanomaly_a916.csv with 2 samples
# Processing file nonanomaly_a917.csv with 2 samples
# Skipping file nonanomaly_a918.csv - too few frames (3 < 5)
# Processing file nonanomaly_a919.csv with 3 samples
# Processing file nonanomaly_a92.csv with 3 samples
# Processing file nonanomaly_a920.csv with 3 samples
# Processing file nonanomaly_a921.csv with 3 samples
# Processing file nonanomaly_a922.csv with 3 samples
# Processing file nonanomaly_a923.csv with 3 samples
# Processing file nonanomaly_a924.csv with 3 samples
# Processing file nonanomaly_a925.csv with 3 samples
# Processing file nonanomaly_a926.csv with 3 samples
# Processing file nonanomaly_a927.csv with 2 samples
# Skipping file nonanomaly_a928.csv - too few frames (4 < 5)
# Processing file nonanomaly_a929.csv with 2 samples
# Processing file nonanomaly_a93.csv with 2 samples
# Processing file nonanomaly_a930.csv with 3 samples
# Processing file nonanomaly_a931.csv with 3 samples
# Processing file nonanomaly_a932.csv with 2 samples
# Processing file nonanomaly_a933.csv with 2 samples
# Processing file nonanomaly_a934.csv with 1 samples
# Skipping file nonanomaly_a935.csv - too few frames (4 < 5)
# Processing file nonanomaly_a936.csv with 2 samples
# Processing file nonanomaly_a937.csv with 3 samples
# Processing file nonanomaly_a938.csv with 2 samples
# Processing file nonanomaly_a939.csv with 3 samples
# Skipping file nonanomaly_a94.csv - too few frames (3 < 5)
# Processing file nonanomaly_a940.csv with 2 samples
# Skipping file nonanomaly_a941.csv - too few frames (4 < 5)
# Processing file nonanomaly_a942.csv with 3 samples
# Processing file nonanomaly_a943.csv with 3 samples
# Skipping file nonanomaly_a944.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a945.csv - too few frames (4 < 5)
# Processing file nonanomaly_a946.csv with 3 samples
# Processing file nonanomaly_a947.csv with 2 samples
# Processing file nonanomaly_a948.csv with 2 samples
# Skipping file nonanomaly_a949.csv - too few frames (4 < 5)
# Processing file nonanomaly_a95.csv with 3 samples
# Processing file nonanomaly_a950.csv with 3 samples
# Processing file nonanomaly_a951.csv with 3 samples
# Processing file nonanomaly_a952.csv with 2 samples
# Skipping file nonanomaly_a953.csv - too few frames (3 < 5)
# Processing file nonanomaly_a954.csv with 3 samples
# Processing file nonanomaly_a955.csv with 3 samples
# Processing file nonanomaly_a956.csv with 1 samples
# Processing file nonanomaly_a957.csv with 3 samples
# Processing file nonanomaly_a958.csv with 2 samples
# Processing file nonanomaly_a959.csv with 2 samples
# Processing file nonanomaly_a96.csv with 3 samples
# Processing file nonanomaly_a960.csv with 3 samples
# Processing file nonanomaly_a961.csv with 3 samples
# Processing file nonanomaly_a962.csv with 3 samples
# Processing file nonanomaly_a963.csv with 2 samples
# Processing file nonanomaly_a964.csv with 2 samples
# Processing file nonanomaly_a965.csv with 1 samples
# Processing file nonanomaly_a966.csv with 3 samples
# Processing file nonanomaly_a967.csv with 3 samples
# Processing file nonanomaly_a968.csv with 3 samples
# Processing file nonanomaly_a969.csv with 3 samples
# Processing file nonanomaly_a97.csv with 3 samples
# Skipping file nonanomaly_a970.csv - too few frames (4 < 5)
# Processing file nonanomaly_a971.csv with 2 samples
# Processing file nonanomaly_a972.csv with 3 samples
# Processing file nonanomaly_a973.csv with 3 samples
# Processing file nonanomaly_a974.csv with 3 samples
# Skipping file nonanomaly_a975.csv - too few frames (4 < 5)
# Processing file nonanomaly_a976.csv with 3 samples
# Skipping file nonanomaly_a977.csv - too few frames (4 < 5)
# Processing file nonanomaly_a978.csv with 2 samples
# Processing file nonanomaly_a979.csv with 3 samples
# Processing file nonanomaly_a98.csv with 3 samples
# Processing file nonanomaly_a980.csv with 3 samples
# Processing file nonanomaly_a981.csv with 2 samples
# Skipping file nonanomaly_a982.csv - too few frames (4 < 5)
# Processing file nonanomaly_a983.csv with 3 samples
# Processing file nonanomaly_a984.csv with 3 samples
# Processing file nonanomaly_a985.csv with 3 samples
# Processing file nonanomaly_a986.csv with 3 samples
# Processing file nonanomaly_a987.csv with 3 samples
# Skipping file nonanomaly_a988.csv - too few frames (4 < 5)
# Processing file nonanomaly_a989.csv with 3 samples
# Processing file nonanomaly_a99.csv with 3 samples
# Generated 5846 samples from data_files\train
# Found 226 files in data_files\test
# Processing file anomaly_a0.csv with 4 samples
# Skipping file anomaly_a1.csv - too few frames (4 < 5)
# Processing file anomaly_a10.csv with 4 samples
# Processing file anomaly_a100.csv with 3 samples
# Processing file anomaly_a101.csv with 3 samples
# Processing file anomaly_a102.csv with 3 samples
# Processing file anomaly_a103.csv with 2 samples
# Processing file anomaly_a104.csv with 3 samples
# Processing file anomaly_a105.csv with 4 samples
# Skipping file anomaly_a106.csv - too few frames (4 < 5)
# Skipping file anomaly_a107.csv - too few frames (3 < 5)
# Skipping file anomaly_a108.csv - too few frames (4 < 5)
# Processing file anomaly_a109.csv with 4 samples
# Processing file anomaly_a11.csv with 4 samples
# Processing file anomaly_a110.csv with 3 samples
# Processing file anomaly_a111.csv with 2 samples
# Processing file anomaly_a112.csv with 3 samples
# Skipping file anomaly_a113.csv - too few frames (4 < 5)
# Processing file anomaly_a114.csv with 3 samples
# Processing file anomaly_a12.csv with 3 samples
# Processing file anomaly_a13.csv with 5 samples
# Processing file anomaly_a14.csv with 3 samples
# Processing file anomaly_a15.csv with 3 samples
# Processing file anomaly_a16.csv with 2 samples
# Processing file anomaly_a17.csv with 5 samples
# Processing file anomaly_a18.csv with 3 samples
# Processing file anomaly_a19.csv with 3 samples
# Processing file anomaly_a2.csv with 5 samples
# Processing file anomaly_a20.csv with 4 samples
# Processing file anomaly_a21.csv with 3 samples
# Processing file anomaly_a22.csv with 3 samples
# Processing file anomaly_a23.csv with 3 samples
# Processing file anomaly_a24.csv with 3 samples
# Processing file anomaly_a25.csv with 5 samples
# Skipping file anomaly_a26.csv - too few frames (4 < 5)
# Processing file anomaly_a27.csv with 3 samples
# Processing file anomaly_a28.csv with 3 samples
# Processing file anomaly_a29.csv with 2 samples
# Processing file anomaly_a3.csv with 4 samples
# Processing file anomaly_a30.csv with 3 samples
# Processing file anomaly_a31.csv with 3 samples
# Processing file anomaly_a32.csv with 5 samples
# Processing file anomaly_a33.csv with 3 samples
# Processing file anomaly_a34.csv with 3 samples
# Skipping file anomaly_a35.csv - too few frames (4 < 5)
# Processing file anomaly_a36.csv with 3 samples
# Processing file anomaly_a37.csv with 3 samples
# Skipping file anomaly_a38.csv - too few frames (4 < 5)
# Processing file anomaly_a39.csv with 4 samples
# Processing file anomaly_a4.csv with 3 samples
# Processing file anomaly_a40.csv with 4 samples
# Processing file anomaly_a41.csv with 3 samples
# Skipping file anomaly_a42.csv - too few frames (4 < 5)
# Processing file anomaly_a43.csv with 3 samples
# Processing file anomaly_a44.csv with 3 samples
# Processing file anomaly_a45.csv with 2 samples
# Processing file anomaly_a46.csv with 3 samples
# Processing file anomaly_a47.csv with 2 samples
# Processing file anomaly_a48.csv with 5 samples
# Processing file anomaly_a49.csv with 2 samples
# Processing file anomaly_a5.csv with 4 samples
# Processing file anomaly_a50.csv with 3 samples
# Skipping file anomaly_a51.csv - too few frames (4 < 5)
# Skipping file anomaly_a52.csv - too few frames (4 < 5)
# Processing file anomaly_a53.csv with 2 samples
# Processing file anomaly_a54.csv with 3 samples
# Processing file anomaly_a55.csv with 3 samples
# Processing file anomaly_a56.csv with 4 samples
# Processing file anomaly_a57.csv with 3 samples
# Processing file anomaly_a58.csv with 3 samples
# Processing file anomaly_a59.csv with 2 samples
# Skipping file anomaly_a6.csv - too few frames (4 < 5)
# Processing file anomaly_a60.csv with 4 samples
# Processing file anomaly_a61.csv with 4 samples
# Skipping file anomaly_a62.csv - too few frames (4 < 5)
# Skipping file anomaly_a63.csv - too few frames (4 < 5)
# Processing file anomaly_a64.csv with 5 samples
# Processing file anomaly_a65.csv with 2 samples
# Processing file anomaly_a66.csv with 4 samples
# Processing file anomaly_a67.csv with 4 samples
# Processing file anomaly_a68.csv with 1 samples
# Processing file anomaly_a69.csv with 2 samples
# Processing file anomaly_a7.csv with 2 samples
# Processing file anomaly_a70.csv with 2 samples
# Processing file anomaly_a71.csv with 4 samples
# Processing file anomaly_a72.csv with 2 samples
# Processing file anomaly_a73.csv with 2 samples
# Processing file anomaly_a74.csv with 3 samples
# Processing file anomaly_a75.csv with 3 samples
# Processing file anomaly_a76.csv with 3 samples
# Processing file anomaly_a77.csv with 3 samples
# Processing file anomaly_a78.csv with 3 samples
# Processing file anomaly_a79.csv with 3 samples
# Processing file anomaly_a8.csv with 3 samples
# Processing file anomaly_a80.csv with 3 samples
# Processing file anomaly_a81.csv with 5 samples
# Skipping file anomaly_a82.csv - too few frames (4 < 5)
# Processing file anomaly_a83.csv with 2 samples
# Processing file anomaly_a84.csv with 5 samples
# Processing file anomaly_a85.csv with 3 samples
# Processing file anomaly_a86.csv with 4 samples
# Processing file anomaly_a87.csv with 3 samples
# Processing file anomaly_a88.csv with 3 samples
# Skipping file anomaly_a89.csv - too few frames (4 < 5)
# Processing file anomaly_a9.csv with 5 samples
# Skipping file anomaly_a90.csv - too few frames (3 < 5)
# Processing file anomaly_a91.csv with 3 samples
# Processing file anomaly_a92.csv with 3 samples
# Processing file anomaly_a93.csv with 3 samples
# Processing file anomaly_a94.csv with 4 samples
# Processing file anomaly_a95.csv with 3 samples
# Processing file anomaly_a96.csv with 3 samples
# Processing file anomaly_a97.csv with 3 samples
# Processing file anomaly_a98.csv with 2 samples
# Processing file anomaly_a99.csv with 1 samples
# Processing file nonanomaly_a0.csv with 2 samples
# Processing file nonanomaly_a1.csv with 2 samples
# Processing file nonanomaly_a10.csv with 2 samples
# Skipping file nonanomaly_a100.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a101.csv - too few frames (3 < 5)
# Processing file nonanomaly_a102.csv with 3 samples
# Processing file nonanomaly_a103.csv with 2 samples
# Skipping file nonanomaly_a104.csv - too few frames (4 < 5)
# Processing file nonanomaly_a105.csv with 3 samples
# Skipping file nonanomaly_a106.csv - too few frames (4 < 5)
# Processing file nonanomaly_a107.csv with 2 samples
# Processing file nonanomaly_a108.csv with 2 samples
# Processing file nonanomaly_a109.csv with 3 samples
# Skipping file nonanomaly_a11.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a110.csv - too few frames (4 < 5)
# Processing file nonanomaly_a12.csv with 3 samples
# Processing file nonanomaly_a13.csv with 3 samples
# Processing file nonanomaly_a14.csv with 3 samples
# Skipping file nonanomaly_a15.csv - too few frames (4 < 5)
# Processing file nonanomaly_a16.csv with 2 samples
# Skipping file nonanomaly_a17.csv - too few frames (4 < 5)
# Processing file nonanomaly_a18.csv with 2 samples
# Skipping file nonanomaly_a19.csv - too few frames (4 < 5)
# Processing file nonanomaly_a2.csv with 3 samples
# Processing file nonanomaly_a20.csv with 2 samples
# Processing file nonanomaly_a21.csv with 3 samples
# Processing file nonanomaly_a22.csv with 1 samples
# Processing file nonanomaly_a23.csv with 3 samples
# Processing file nonanomaly_a24.csv with 3 samples
# Processing file nonanomaly_a25.csv with 3 samples
# Processing file nonanomaly_a26.csv with 3 samples
# Processing file nonanomaly_a27.csv with 4 samples
# Processing file nonanomaly_a28.csv with 1 samples
# Processing file nonanomaly_a29.csv with 3 samples
# Skipping file nonanomaly_a3.csv - too few frames (3 < 5)
# Processing file nonanomaly_a30.csv with 3 samples
# Processing file nonanomaly_a31.csv with 2 samples
# Processing file nonanomaly_a32.csv with 3 samples
# Processing file nonanomaly_a33.csv with 2 samples
# Processing file nonanomaly_a34.csv with 3 samples
# Processing file nonanomaly_a35.csv with 4 samples
# Skipping file nonanomaly_a36.csv - too few frames (4 < 5)
# Processing file nonanomaly_a37.csv with 3 samples
# Processing file nonanomaly_a38.csv with 3 samples
# Processing file nonanomaly_a39.csv with 3 samples
# Processing file nonanomaly_a4.csv with 3 samples
# Skipping file nonanomaly_a40.csv - too few frames (4 < 5)
# Processing file nonanomaly_a41.csv with 2 samples
# Processing file nonanomaly_a42.csv with 3 samples
# Processing file nonanomaly_a43.csv with 2 samples
# Processing file nonanomaly_a44.csv with 2 samples
# Processing file nonanomaly_a45.csv with 3 samples
# Processing file nonanomaly_a46.csv with 3 samples
# Processing file nonanomaly_a47.csv with 2 samples
# Processing file nonanomaly_a48.csv with 3 samples
# Processing file nonanomaly_a49.csv with 2 samples
# Skipping file nonanomaly_a5.csv - too few frames (3 < 5)
# Processing file nonanomaly_a50.csv with 3 samples
# Processing file nonanomaly_a51.csv with 2 samples
# Processing file nonanomaly_a52.csv with 3 samples
# Processing file nonanomaly_a53.csv with 3 samples
# Processing file nonanomaly_a54.csv with 3 samples
# Processing file nonanomaly_a55.csv with 3 samples
# Processing file nonanomaly_a56.csv with 4 samples
# Skipping file nonanomaly_a57.csv - too few frames (4 < 5)
# Processing file nonanomaly_a58.csv with 2 samples
# Processing file nonanomaly_a59.csv with 3 samples
# Processing file nonanomaly_a6.csv with 3 samples
# Skipping file nonanomaly_a60.csv - too few frames (4 < 5)
# Processing file nonanomaly_a61.csv with 3 samples
# Skipping file nonanomaly_a62.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a63.csv - too few frames (4 < 5)
# Processing file nonanomaly_a64.csv with 3 samples
# Processing file nonanomaly_a65.csv with 2 samples
# Processing file nonanomaly_a66.csv with 3 samples
# Processing file nonanomaly_a67.csv with 3 samples
# Skipping file nonanomaly_a68.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a69.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a7.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a70.csv - too few frames (4 < 5)
# Processing file nonanomaly_a71.csv with 3 samples
# Processing file nonanomaly_a72.csv with 2 samples
# Processing file nonanomaly_a73.csv with 2 samples
# Processing file nonanomaly_a74.csv with 2 samples
# Processing file nonanomaly_a75.csv with 2 samples
# Processing file nonanomaly_a76.csv with 3 samples
# Processing file nonanomaly_a77.csv with 3 samples
# Processing file nonanomaly_a78.csv with 2 samples
# Skipping file nonanomaly_a79.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a8.csv - too few frames (4 < 5)
# Processing file nonanomaly_a80.csv with 3 samples
# Processing file nonanomaly_a81.csv with 3 samples
# Processing file nonanomaly_a82.csv with 3 samples
# Processing file nonanomaly_a83.csv with 3 samples
# Processing file nonanomaly_a84.csv with 3 samples
# Processing file nonanomaly_a85.csv with 2 samples
# Skipping file nonanomaly_a86.csv - too few frames (4 < 5)
# Processing file nonanomaly_a87.csv with 3 samples
# Skipping file nonanomaly_a88.csv - too few frames (2 < 5)
# Skipping file nonanomaly_a89.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a9.csv - too few frames (3 < 5)
# Processing file nonanomaly_a90.csv with 3 samples
# Processing file nonanomaly_a91.csv with 3 samples
# Processing file nonanomaly_a92.csv with 2 samples
# Processing file nonanomaly_a93.csv with 3 samples
# Processing file nonanomaly_a94.csv with 1 samples
# Processing file nonanomaly_a95.csv with 3 samples
# Processing file nonanomaly_a96.csv with 4 samples
# Processing file nonanomaly_a97.csv with 2 samples
# Processing file nonanomaly_a98.csv with 3 samples
# Processing file nonanomaly_a99.csv with 2 samples
# Generated 533 samples from data_files\test

# %%
print('num of train_samples: {}'.format(len(train_data)))

print('num of test_samples: {}'.format(len(test_data)))
# Out:
# num of train_samples: 5846
# num of test_samples: 533

# %%
train_generator = data_gen_obj.data_generator(train_data,batch_size=10,shuffle=True)

test_generator = data_gen_obj.data_generator(test_data,batch_size=10,shuffle=True)

# %%
Callback_Stop_Early = tf.keras.callbacks.EarlyStopping(monitor="loss",patience=3,mode='auto')

# %%
def get_model():
    # Define model
    model = Sequential()
    model.add(Conv3D(32, kernel_size=(3, 3, 3), input_shape=(
        5,224,224,3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv3D(32, kernel_size=(3, 3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(MaxPooling3D(pool_size=(3, 3, 3), padding='same'))
    model.add(Dropout(0.25))

    model.add(Conv3D(64, kernel_size=(3, 3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv3D(64, kernel_size=(3, 3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(MaxPooling3D(pool_size=(3, 3, 3), padding='same'))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(2))
    model.add(Activation("softmax"))
    model.compile(loss=categorical_crossentropy,
                  optimizer=Adam(), metrics=['accuracy'])
    model.summary()
    #plot_model(model, show_shapes=True,


    #           to_file='model.png')
    return model

# %%
model = get_model()
# Out:
# c:\Users\srhan\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d (Conv3D)                 │ (None, 5, 224, 224,    │         2,624 │
# │                                 │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 5, 224, 224,    │             0 │
# │                                 │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 5, 224, 224,    │        27,680 │
# │                                 │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 5, 224, 224,    │             0 │
# │                                 │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 2, 75, 75, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 2, 75, 75, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_2 (Conv3D)               │ (None, 2, 75, 75, 64)  │        55,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 2, 75, 75, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_3 (Conv3D)               │ (None, 2, 75, 75, 64)  │       110,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 2, 75, 75, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 1, 25, 25, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1, 25, 25, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 40000)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    20,480,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │         1,026 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 2)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,677,858 (78.88 MB)
#  Trainable params: 20,677,858 (78.88 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.utils import to_categorical

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_data) // 10,
    epochs=10,
    callbacks=[Callback_Stop_Early],
    validation_data=test_generator,
    validation_steps=len(test_data) // 10
)
# Out:
# Epoch 1/10
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 1923s 3s/step - accuracy: 0.6672 - loss: 0.6234 - val_accuracy: 0.7830 - val_loss: 0.4565
# Epoch 2/10
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 1882s 3s/step - accuracy: 0.8076 - loss: 0.4228 - val_accuracy: 0.7304 - val_loss: 0.5254
# Epoch 3/10
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 1796s 3s/step - accuracy: 0.8495 - loss: 0.3401 - val_accuracy: 0.8031 - val_loss: 0.4765
# Epoch 4/10
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 1974s 3s/step - accuracy: 0.8664 - loss: 0.2854 - val_accuracy: 0.7973 - val_loss: 0.5420
# Epoch 5/10
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 2150s 4s/step - accuracy: 0.8945 - loss: 0.2461 - val_accuracy: 0.8470 - val_loss: 0.4007
# Epoch 6/10
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 2151s 4s/step - accuracy: 0.9136 - loss: 0.2077 - val_accuracy: 0.8700 - val_loss: 0.3902
# Epoch 7/10
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 1876s 3s/step - accuracy: 0.9388 - loss: 0.1601 - val_accuracy: 0.8604 - val_loss: 0.4270
# Epoch 8/10
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 1974s 3s/step - accuracy: 0.9411 - loss: 0.1660 - val_accuracy: 0.8432 - val_loss: 0.4669
# Epoch 9/10
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 2147s 4s/step - accuracy: 0.9597 - loss: 0.1131 - val_accuracy: 0.8298 - val_loss: 0.5076
# Epoch 10/10
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 2151s 4s/step - accuracy: 0.9657 - loss: 0.0961 - val_accuracy: 0.8585 - val_loss: 0.5785

# %%
model.save("./anomalyModel.hdf5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
sns.set()
# Summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.xticks(range(1, len(history.history['accuracy']) + 1))  # Adjusting to show all epochs
plt.show()

# Summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.xticks(range(1, len(history.history['loss']) + 1))  # Adjusting to show all epochs
plt.show()

# %%
model.save('./anomalyModel.keras')
