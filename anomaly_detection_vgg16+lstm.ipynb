# %%
import numpy as np
import pandas as pd
import cv2
import os
import math
import copy
import imageio
import seaborn as sns
from glob import glob
from pathlib import Path
from collections import deque
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
from IPython.display import Image
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import seaborn as sns
import plotly.express as px
from IPython.display import SVG
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.applications import VGG16, inception_v3
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import RMSprop, Adam, SGD
from tensorflow.keras.layers import Input, Lambda, Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, MaxPooling2D, \
    Permute, TimeDistributed, Bidirectional, GRU, SimpleRNN, LSTM, GlobalAveragePooling2D, SeparableConv2D, ZeroPadding2D, Convolution2D, ZeroPadding2D, \
    Reshape, Conv2DTranspose, LeakyReLU, Conv1D, AveragePooling1D, MaxPooling1D, Activation, Conv3D, MaxPooling3D

# %%
Main_Video_Path = Path("./dataset/anomaly1")
Video_Path = list(Main_Video_Path.glob(r"*/*.mp4"))
Video_Labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1],Video_Path))
Video_Path_Series = pd.Series(Video_Path,name="MP4").astype(str)
Video_Labels_Series = pd.Series(Video_Labels,name="CATEGORY")
Main_MP4_Data = pd.concat([Video_Path_Series,Video_Labels_Series],axis=1)

# %%
Anomaly_Data = Main_MP4_Data[Main_MP4_Data["CATEGORY"] == "fight"]
NonAnomaly_Data = Main_MP4_Data[Main_MP4_Data["CATEGORY"] == "noFight"]

Anomaly_Data = Anomaly_Data.reset_index()
NonAnomaly_Data = NonAnomaly_Data.reset_index()

# %%
Anomaly_Data
# Out:
#      index                               MP4 CATEGORY
# 0        0  dataset\anomaly1\fight\fi001.mp4    fight
# 1        1  dataset\anomaly1\fight\fi002.mp4    fight
# 2        2  dataset\anomaly1\fight\fi003.mp4    fight
# 3        3  dataset\anomaly1\fight\fi004.mp4    fight
# 4        4  dataset\anomaly1\fight\fi005.mp4    fight
# ..     ...                               ...      ...
# 145    145  dataset\anomaly1\fight\fi146.mp4    fight
# 146    146  dataset\anomaly1\fight\fi147.mp4    fight
# 147    147  dataset\anomaly1\fight\fi148.mp4    fight
# 148    148  dataset\anomaly1\fight\fi149.mp4    fight
# 149    149  dataset\anomaly1\fight\fi150.mp4    fight
#
# [150 rows x 3 columns]

# %%
NonAnomaly_Data
# Out:
#      index                                   MP4 CATEGORY
# 0      150  dataset\anomaly1\noFight\nofi001.mp4  noFight
# 1      151  dataset\anomaly1\noFight\nofi002.mp4  noFight
# 2      152  dataset\anomaly1\noFight\nofi003.mp4  noFight
# 3      153  dataset\anomaly1\noFight\nofi004.mp4  noFight
# 4      154  dataset\anomaly1\noFight\nofi005.mp4  noFight
# ..     ...                                   ...      ...
# 145    295  dataset\anomaly1\noFight\nofi146.mp4  noFight
# 146    296  dataset\anomaly1\noFight\nofi147.mp4  noFight
# 147    297  dataset\anomaly1\noFight\nofi148.mp4  noFight
# 148    298  dataset\anomaly1\noFight\nofi149.mp4  noFight
# 149    299  dataset\anomaly1\noFight\nofi150.mp4  noFight
#
# [150 rows x 3 columns]

# %%
Main_Video_Path = Path("./dataset/anomaly2/Real Life Violence Dataset")
Video_Path = list(Main_Video_Path.glob(r"*/*.mp4"))
Video_Labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1],Video_Path))
Video_Path_Series = pd.Series(Video_Path,name="MP4").astype(str)
Video_Labels_Series = pd.Series(Video_Labels,name="CATEGORY")
Main_MP4_Data = pd.concat([Video_Path_Series,Video_Labels_Series],axis=1)

# %%
Main_MP4_Data["CATEGORY"].replace({'Violence':'fight','NonViolence':'noFight'}, inplace=True)
AD = Main_MP4_Data[Main_MP4_Data["CATEGORY"] == "fight"]
NAD = Main_MP4_Data[Main_MP4_Data["CATEGORY"] == "noFight"]
# Out:
# C:\Users\srhan\AppData\Local\Temp\ipykernel_22376\50674731.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Main_MP4_Data["CATEGORY"].replace({'Violence':'fight','NonViolence':'noFight'}, inplace=True)

# %%
AD
# Out:
#                                                     MP4 CATEGORY
# 951   dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 952   dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 953   dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 954   dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 955   dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# ...                                                 ...      ...
# 1946  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 1947  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 1948  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 1949  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 1950  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
#
# [1000 rows x 2 columns]

# %%
NAD
# Out:
#                                                    MP4 CATEGORY
# 0    dataset\anomaly2\Real Life Violence Dataset\No...  noFight
# 1    dataset\anomaly2\Real Life Violence Dataset\No...  noFight
# 2    dataset\anomaly2\Real Life Violence Dataset\No...  noFight
# 3    dataset\anomaly2\Real Life Violence Dataset\No...  noFight
# 4    dataset\anomaly2\Real Life Violence Dataset\No...  noFight
# ..                                                 ...      ...
# 946  dataset\anomaly2\Real Life Violence Dataset\No...  noFight
# 947  dataset\anomaly2\Real Life Violence Dataset\No...  noFight
# 948  dataset\anomaly2\Real Life Violence Dataset\No...  noFight
# 949  dataset\anomaly2\Real Life Violence Dataset\No...  noFight
# 950  dataset\anomaly2\Real Life Violence Dataset\No...  noFight
#
# [951 rows x 2 columns]

# %%
Anomaly_Data = pd.concat([Anomaly_Data, AD], ignore_index=True, sort=False)
NonAnomaly_Data = pd.concat([NonAnomaly_Data, NAD], ignore_index=True, sort=False)

# %%
Anomaly_Data
# Out:
#       index                                                MP4 CATEGORY
# 0       0.0                   dataset\anomaly1\fight\fi001.mp4    fight
# 1       1.0                   dataset\anomaly1\fight\fi002.mp4    fight
# 2       2.0                   dataset\anomaly1\fight\fi003.mp4    fight
# 3       3.0                   dataset\anomaly1\fight\fi004.mp4    fight
# 4       4.0                   dataset\anomaly1\fight\fi005.mp4    fight
# ...     ...                                                ...      ...
# 1145    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 1146    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 1147    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 1148    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 1149    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
#
# [1150 rows x 3 columns]

# %%
NonAnomaly_Data
# Out:
#       index                                                MP4 CATEGORY
# 0     150.0               dataset\anomaly1\noFight\nofi001.mp4  noFight
# 1     151.0               dataset\anomaly1\noFight\nofi002.mp4  noFight
# 2     152.0               dataset\anomaly1\noFight\nofi003.mp4  noFight
# 3     153.0               dataset\anomaly1\noFight\nofi004.mp4  noFight
# 4     154.0               dataset\anomaly1\noFight\nofi005.mp4  noFight
# ...     ...                                                ...      ...
# 1096    NaN  dataset\anomaly2\Real Life Violence Dataset\No...  noFight
# 1097    NaN  dataset\anomaly2\Real Life Violence Dataset\No...  noFight
# 1098    NaN  dataset\anomaly2\Real Life Violence Dataset\No...  noFight
# 1099    NaN  dataset\anomaly2\Real Life Violence Dataset\No...  noFight
# 1100    NaN  dataset\anomaly2\Real Life Violence Dataset\No...  noFight
#
# [1101 rows x 3 columns]

# %% [markdown]
# **Merging all different Data**

# %%
Cdata = NonAnomaly_Data

# %%
Cdata = pd.concat([NonAnomaly_Data, Anomaly_Data], ignore_index=True, sort=False)

# %%
Cdata
# Out:
#       index                                                MP4 CATEGORY
# 0     150.0               dataset\anomaly1\noFight\nofi001.mp4  noFight
# 1     151.0               dataset\anomaly1\noFight\nofi002.mp4  noFight
# 2     152.0               dataset\anomaly1\noFight\nofi003.mp4  noFight
# 3     153.0               dataset\anomaly1\noFight\nofi004.mp4  noFight
# 4     154.0               dataset\anomaly1\noFight\nofi005.mp4  noFight
# ...     ...                                                ...      ...
# 2246    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 2247    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 2248    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 2249    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
# 2250    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...    fight
#
# [2251 rows x 3 columns]

# %%
Cdata["CATEGORY"].replace({'fight':1,'noFight':0}, inplace=True)
# Out:
# C:\Users\srhan\AppData\Local\Temp\ipykernel_22376\1989987325.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Cdata["CATEGORY"].replace({'fight':1,'noFight':0}, inplace=True)
# C:\Users\srhan\AppData\Local\Temp\ipykernel_22376\1989987325.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Cdata["CATEGORY"].replace({'fight':1,'noFight':0}, inplace=True)

# %%
Cdata
# Out:
#       index                                                MP4  CATEGORY
# 0     150.0               dataset\anomaly1\noFight\nofi001.mp4         0
# 1     151.0               dataset\anomaly1\noFight\nofi002.mp4         0
# 2     152.0               dataset\anomaly1\noFight\nofi003.mp4         0
# 3     153.0               dataset\anomaly1\noFight\nofi004.mp4         0
# 4     154.0               dataset\anomaly1\noFight\nofi005.mp4         0
# ...     ...                                                ...       ...
# 2246    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...         1
# 2247    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...         1
# 2248    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...         1
# 2249    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...         1
# 2250    NaN  dataset\anomaly2\Real Life Violence Dataset\Vi...         1
#
# [2251 rows x 3 columns]

# %% [markdown]
# ## **Video Preprocessing**

# %%
Anomaly_Data.MP4[1]
# Out:
# 'dataset\\anomaly1\\fight\\fi002.mp4'

# %%
import os

os.makedirs('./dataset/Frames', exist_ok=True)

# %%
a_train, a_valid = train_test_split(Anomaly_Data.MP4, test_size=0.4, random_state=17)
print("a_train {} samples, a_valid {} samples".format(len(a_train), len(a_valid)))
# Out:
# a_train 690 samples, a_valid 460 samples

# %%
na_train, na_valid = train_test_split(NonAnomaly_Data.MP4, test_size=0.4, random_state=17)
print("na_train {} samples, na_valid {} samples".format(len(na_train), len(na_valid)))
# Out:
# na_train 660 samples, na_valid 441 samples

# %%
os.makedirs('./dataset/Frames/train', exist_ok=True)
os.makedirs('./dataset/Frames/test', exist_ok=True)
os.makedirs('./dataset/Frames/train/nonanomaly', exist_ok=True)
os.makedirs('./dataset/Frames/test/nonanomaly', exist_ok=True)
os.makedirs('./dataset/Frames/train/anomaly', exist_ok=True)
os.makedirs('./dataset/Frames/test/anomaly', exist_ok=True)

# %%
def make_frames(df,tag,sset):
    a = 0
    for file_video in df:
        Video_File_Path = file_video

        Video_Caption = cv2.VideoCapture(Video_File_Path)
        Frame_Rate = 15
        count = 0
        temp = []
        if Video_Caption.isOpened():
            os.mkdir('./dataset/Frames/{}/{}/a{}'.format(sset,tag,a))
        while Video_Caption.isOpened():

            Current_Frame_ID = Video_Caption.get(1)

            ret,frame = Video_Caption.read()

            if ret != True:
                break

            if Current_Frame_ID % math.floor(Frame_Rate) == 0:
                image = cv2.resize(frame,(256,256))
                cv2.imwrite("./dataset/Frames/{}/{}/a{}/frame{}.jpg".format(sset,tag,a,count), image)
                count += 1
        a += 1

        Video_Caption.release()

# %%
make_frames(a_train,tag='anomaly',sset='train')

# %%
make_frames(a_valid,tag='anomaly',sset='test')

# %%
make_frames(na_train,tag='nonanomaly',sset='train')

# %%
make_frames(na_valid,tag='nonanomaly',sset='test')

# %%
sorted(os.listdir("./dataset/Frames/test"))
# Out:
# ['anomaly', 'nonanomaly']

# %%
class Config():
    def __init__(self):
        pass

    num_classes=2
    labels_to_class = {0:'nonanomaly',1:'anomaly'}
    class_to_labels = {'nonanomaly':0,'anomaly':1}
    resize = 224
    num_epochs =10
    batch_size =10

# %%
train_data_path = './dataset/Frames/train'
test_data_path = "./dataset/Frames/test"

# %%
if not os.path.exists('data_files'):
    os.mkdir('data_files')
if not os.path.exists('data_files/train'):
    os.mkdir('data_files/train')
if not os.path.exists('data_files/test'):
    os.mkdir('data_files/test')

# %%
num_classes = 2
labels_name={'nonanomaly':0,'anomaly':1}

# %%
data_dir_list = os.listdir(train_data_path)
data_dir_list
# Out:
# ['anomaly', 'nonanomaly']

# %%
import os
import pandas as pd

def make_train(train_data_path):
    data_dir_list = os.listdir(train_data_path)
    for data_dir in data_dir_list:  # looping over every activity
        label = labels_name[str(data_dir)]
        video_list = os.listdir(os.path.join(train_data_path, data_dir))
        for vid in video_list:  # looping over every video within an activity
            train_df = pd.DataFrame(columns=['FileName', 'Label', 'ClassName'])
            img_list = os.listdir(os.path.join(train_data_path, data_dir, vid))
            for img in img_list:  # looping over every frame within the video
                img_path = os.path.join(train_data_path, data_dir, vid, img)
                # Create a temporary DataFrame for the new row
                new_row = pd.DataFrame({'FileName': [img_path], 'Label': [label], 'ClassName': [data_dir]})
                # Concatenate with the existing DataFrame
                train_df = pd.concat([train_df, new_row], ignore_index=True)
            file_name = '{}_{}.csv'.format(data_dir, vid)
            train_df.to_csv('data_files/train/{}'.format(file_name), index=False)

make_train(train_data_path)

# %%
def make_test(test_data_path):
    data_dir_list = os.listdir(test_data_path)
    for data_dir in data_dir_list:  # looping over every activity
        label = labels_name[str(data_dir)]
        video_list = os.listdir(os.path.join(test_data_path, data_dir))
        for vid in video_list:  # looping over every video within an activity
            test_df = pd.DataFrame(columns=['FileName', 'Label', 'ClassName'])
            img_list = os.listdir(os.path.join(test_data_path, data_dir, vid))
            for img in img_list:  # looping over every frame within the video
                img_path = os.path.join(test_data_path, data_dir, vid, img)
                # Create a temporary DataFrame for the new row
                new_row = pd.DataFrame({'FileName': [img_path], 'Label': [label], 'ClassName': [data_dir]})
                # Concatenate with the existing DataFrame
                test_df = pd.concat([test_df, new_row], ignore_index=True)
            file_name = '{}_{}.csv'.format(data_dir, vid)
            test_df.to_csv('data_files/test/{}'.format(file_name), index=False)

make_test(test_data_path)

# %%
class ActionDataGenerator(object):
    def __init__(self, root_data_path, temporal_stride=1, temporal_length=16, resize=224):
        self.root_data_path = root_data_path
        self.temporal_length = temporal_length
        self.temporal_stride = temporal_stride
        self.resize = resize

    def file_generator(self, data_path, data_files):
        '''
        data_files - list of csv files to be read.
        '''
        if not data_files:
            print("Warning: No data files found in", data_path)
            return

        for f in data_files:
            try:
                file_path = os.path.join(data_path, f)
                if not os.path.exists(file_path):
                    print(f"Warning: File {file_path} does not exist")
                    continue

                tmp_df = pd.read_csv(file_path)
                if tmp_df.empty:
                    print(f"Warning: Empty CSV file - {f}")
                    continue

                label_list = list(tmp_df['Label'])
                total_images = len(label_list)

                if total_images >= self.temporal_length:
                    num_samples = int((total_images-self.temporal_length)/self.temporal_stride)+1
                    print(f'Processing file {f} with {num_samples} samples')
                    img_list = list(tmp_df['FileName'])
                else:
                    print(f'Skipping file {f} - too few frames ({total_images} < {self.temporal_length})')
                    continue

                samples = deque(maxlen=self.temporal_length)
                for img in img_list:
                    if not os.path.exists(img):
                        print(f"Warning: Image file does not exist - {img}")
                        continue
                    samples.append(img)
                    if len(samples) == self.temporal_length:
                        samples_c = copy.deepcopy(samples)
                        yield list(samples_c), label_list[0]
                        for _ in range(self.temporal_stride):
                            if samples:
                                samples.popleft()

            except Exception as e:
                print(f"Error processing file {f}: {str(e)}")
                continue

    def load_samples(self, data_cat='train'):
        data_path = os.path.join(self.root_data_path, data_cat)
        if not os.path.exists(data_path):
            raise ValueError(f"Data path does not exist: {data_path}")

        csv_data_files = os.listdir(data_path)
        if not csv_data_files:
            raise ValueError(f"No files found in {data_path}")

        print(f"Found {len(csv_data_files)} files in {data_path}")

        file_gen = self.file_generator(data_path, csv_data_files)
        data_list = []

        for x, y in file_gen:
            data_list.append([x, y])

        if not data_list:
            raise ValueError("No valid samples were generated")

        print(f"Generated {len(data_list)} samples from {data_path}")
        return data_list

    def data_generator(self, data, batch_size=10, shuffle=True):
        """
        Yields the next training batch.
        """
        if not data:
            raise ValueError("Empty data provided to generator")

        num_samples = len(data)
        if shuffle:
            data = self.shuffle_data(data)

        while True:
            for offset in range(0, num_samples, batch_size):
                batch_samples = data[offset:offset+batch_size]
                X_train = []
                y_train = []

                for batch_sample in batch_samples:
                    try:
                        x = batch_sample[0]
                        y = batch_sample[1]
                        temp_data_list = []

                        for img_path in x:
                            try:
                                if not os.path.exists(img_path):
                                    raise FileNotFoundError(f"Image not found: {img_path}")

                                img = cv2.imread(img_path)
                                if img is None:
                                    raise ValueError(f"Failed to read image: {img_path}")

                                img = self.preprocess_image(img)
                                temp_data_list.append(img)

                            except Exception as e:
                                print(f"Error processing image {img_path}: {str(e)}")
                                raise

                        if len(temp_data_list) == self.temporal_length:
                            X_train.append(temp_data_list)
                            y_train.append(y)

                    except Exception as e:
                        print(f"Error processing batch sample: {str(e)}")
                        continue

                if not X_train or not y_train:
                    print("Warning: Empty batch generated, skipping...")
                    continue

                X_train = np.array(X_train)
                y_train = np.array(y_train)
                y_train = to_categorical(y_train, 2)

                yield X_train, y_train

    def shuffle_data(self, samples):
        return shuffle(samples, random_state=2)

    def preprocess_image(self, img):
        img = cv2.resize(img, (self.resize, self.resize))
        img = img/255.0
        return img

# %%
# Set your paths
root_data_path = 'data_files'
train_data_path = 'path/to/your/train/data'
test_data_path = 'path/to/your/test/data'

# Create directories if they don't exist
os.makedirs('data_files/train', exist_ok=True)
os.makedirs('data_files/test', exist_ok=True)

# %%
data_gen_obj = ActionDataGenerator(root_data_path, temporal_stride=2, temporal_length=5)

# %%
train_data = data_gen_obj.load_samples(data_cat='train')

test_data = data_gen_obj.load_samples(data_cat='test')
# Out:
# Found 1350 files in data_files\train
# Processing file anomaly_a0.csv with 4 samples
# Processing file anomaly_a1.csv with 3 samples
# Processing file anomaly_a10.csv with 4 samples
# Processing file anomaly_a100.csv with 5 samples
# Processing file anomaly_a101.csv with 3 samples
# Processing file anomaly_a102.csv with 3 samples
# Processing file anomaly_a103.csv with 3 samples
# Processing file anomaly_a104.csv with 4 samples
# Processing file anomaly_a105.csv with 3 samples
# Skipping file anomaly_a106.csv - too few frames (4 < 5)
# Processing file anomaly_a107.csv with 5 samples
# Processing file anomaly_a108.csv with 4 samples
# Processing file anomaly_a109.csv with 4 samples
# Processing file anomaly_a11.csv with 5 samples
# Skipping file anomaly_a110.csv - too few frames (3 < 5)
# Processing file anomaly_a111.csv with 3 samples
# Processing file anomaly_a112.csv with 1 samples
# Processing file anomaly_a113.csv with 2 samples
# Processing file anomaly_a114.csv with 5 samples
# Skipping file anomaly_a115.csv - too few frames (4 < 5)
# Processing file anomaly_a116.csv with 3 samples
# Processing file anomaly_a117.csv with 4 samples
# Processing file anomaly_a118.csv with 4 samples
# Processing file anomaly_a119.csv with 3 samples
# Processing file anomaly_a12.csv with 4 samples
# Processing file anomaly_a120.csv with 4 samples
# Skipping file anomaly_a121.csv - too few frames (4 < 5)
# Processing file anomaly_a122.csv with 3 samples
# Processing file anomaly_a123.csv with 3 samples
# Processing file anomaly_a124.csv with 5 samples
# Processing file anomaly_a125.csv with 2 samples
# Processing file anomaly_a126.csv with 4 samples
# Skipping file anomaly_a127.csv - too few frames (4 < 5)
# Processing file anomaly_a128.csv with 4 samples
# Processing file anomaly_a129.csv with 3 samples
# Processing file anomaly_a13.csv with 3 samples
# Processing file anomaly_a130.csv with 2 samples
# Processing file anomaly_a131.csv with 3 samples
# Processing file anomaly_a132.csv with 4 samples
# Processing file anomaly_a133.csv with 3 samples
# Processing file anomaly_a134.csv with 5 samples
# Processing file anomaly_a135.csv with 3 samples
# Processing file anomaly_a136.csv with 4 samples
# Processing file anomaly_a137.csv with 1 samples
# Skipping file anomaly_a138.csv - too few frames (3 < 5)
# Processing file anomaly_a139.csv with 4 samples
# Skipping file anomaly_a14.csv - too few frames (2 < 5)
# Processing file anomaly_a140.csv with 5 samples
# Processing file anomaly_a141.csv with 3 samples
# Processing file anomaly_a142.csv with 3 samples
# Processing file anomaly_a143.csv with 3 samples
# Processing file anomaly_a144.csv with 4 samples
# Processing file anomaly_a145.csv with 2 samples
# Processing file anomaly_a146.csv with 5 samples
# Processing file anomaly_a147.csv with 4 samples
# Processing file anomaly_a148.csv with 2 samples
# Processing file anomaly_a149.csv with 4 samples
# Processing file anomaly_a15.csv with 3 samples
# Processing file anomaly_a150.csv with 3 samples
# Processing file anomaly_a151.csv with 3 samples
# Processing file anomaly_a152.csv with 4 samples
# Processing file anomaly_a153.csv with 2 samples
# Processing file anomaly_a154.csv with 2 samples
# Processing file anomaly_a155.csv with 3 samples
# Processing file anomaly_a156.csv with 4 samples
# Processing file anomaly_a157.csv with 2 samples
# Processing file anomaly_a158.csv with 3 samples
# Processing file anomaly_a159.csv with 3 samples
# Processing file anomaly_a16.csv with 3 samples
# Skipping file anomaly_a160.csv - too few frames (4 < 5)
# Processing file anomaly_a161.csv with 5 samples
# Processing file anomaly_a162.csv with 2 samples
# Processing file anomaly_a163.csv with 3 samples
# Processing file anomaly_a164.csv with 2 samples
# Skipping file anomaly_a165.csv - too few frames (2 < 5)
# Processing file anomaly_a166.csv with 4 samples
# Processing file anomaly_a167.csv with 4 samples
# Processing file anomaly_a168.csv with 2 samples
# Processing file anomaly_a169.csv with 3 samples
# Processing file anomaly_a17.csv with 3 samples
# Processing file anomaly_a170.csv with 3 samples
# Processing file anomaly_a171.csv with 5 samples
# Processing file anomaly_a172.csv with 3 samples
# Skipping file anomaly_a173.csv - too few frames (4 < 5)
# Processing file anomaly_a174.csv with 2 samples
# Processing file anomaly_a175.csv with 2 samples
# Processing file anomaly_a176.csv with 3 samples
# Processing file anomaly_a177.csv with 5 samples
# Processing file anomaly_a178.csv with 3 samples
# Processing file anomaly_a179.csv with 4 samples
# Processing file anomaly_a18.csv with 3 samples
# Processing file anomaly_a180.csv with 5 samples
# Processing file anomaly_a181.csv with 3 samples
# Processing file anomaly_a182.csv with 3 samples
# Processing file anomaly_a183.csv with 5 samples
# Processing file anomaly_a184.csv with 3 samples
# Processing file anomaly_a185.csv with 3 samples
# Processing file anomaly_a186.csv with 3 samples
# Processing file anomaly_a187.csv with 3 samples
# Processing file anomaly_a188.csv with 3 samples
# Processing file anomaly_a189.csv with 3 samples
# Processing file anomaly_a19.csv with 3 samples
# Processing file anomaly_a190.csv with 2 samples
# Processing file anomaly_a191.csv with 3 samples
# Processing file anomaly_a192.csv with 4 samples
# Processing file anomaly_a193.csv with 5 samples
# Processing file anomaly_a194.csv with 2 samples
# Processing file anomaly_a195.csv with 4 samples
# Processing file anomaly_a196.csv with 3 samples
# Processing file anomaly_a197.csv with 4 samples
# Processing file anomaly_a198.csv with 3 samples
# Processing file anomaly_a199.csv with 1 samples
# Processing file anomaly_a2.csv with 3 samples
# Processing file anomaly_a20.csv with 3 samples
# Processing file anomaly_a200.csv with 4 samples
# Processing file anomaly_a201.csv with 4 samples
# Processing file anomaly_a202.csv with 3 samples
# Processing file anomaly_a203.csv with 3 samples
# Processing file anomaly_a204.csv with 5 samples
# Processing file anomaly_a205.csv with 4 samples
# Processing file anomaly_a206.csv with 4 samples
# Processing file anomaly_a207.csv with 2 samples
# Processing file anomaly_a208.csv with 3 samples
# Processing file anomaly_a209.csv with 4 samples
# Processing file anomaly_a21.csv with 4 samples
# Processing file anomaly_a210.csv with 3 samples
# Processing file anomaly_a211.csv with 4 samples
# Skipping file anomaly_a212.csv - too few frames (4 < 5)
# Processing file anomaly_a213.csv with 4 samples
# Processing file anomaly_a214.csv with 3 samples
# Processing file anomaly_a215.csv with 5 samples
# Processing file anomaly_a216.csv with 3 samples
# Processing file anomaly_a217.csv with 2 samples
# Processing file anomaly_a218.csv with 3 samples
# Skipping file anomaly_a219.csv - too few frames (4 < 5)
# Processing file anomaly_a22.csv with 3 samples
# Skipping file anomaly_a220.csv - too few frames (4 < 5)
# Processing file anomaly_a221.csv with 3 samples
# Processing file anomaly_a222.csv with 3 samples
# Processing file anomaly_a223.csv with 1 samples
# Processing file anomaly_a224.csv with 4 samples
# Processing file anomaly_a225.csv with 3 samples
# Processing file anomaly_a226.csv with 3 samples
# Processing file anomaly_a227.csv with 3 samples
# Processing file anomaly_a228.csv with 3 samples
# Processing file anomaly_a229.csv with 5 samples
# Processing file anomaly_a23.csv with 4 samples
# Processing file anomaly_a230.csv with 3 samples
# Processing file anomaly_a231.csv with 3 samples
# Skipping file anomaly_a232.csv - too few frames (2 < 5)
# Processing file anomaly_a233.csv with 4 samples
# Processing file anomaly_a234.csv with 2 samples
# Processing file anomaly_a235.csv with 4 samples
# Processing file anomaly_a236.csv with 2 samples
# Processing file anomaly_a237.csv with 3 samples
# Processing file anomaly_a238.csv with 5 samples
# Skipping file anomaly_a239.csv - too few frames (4 < 5)
# Processing file anomaly_a24.csv with 4 samples
# Processing file anomaly_a240.csv with 3 samples
# Processing file anomaly_a241.csv with 3 samples
# Skipping file anomaly_a242.csv - too few frames (4 < 5)
# Processing file anomaly_a243.csv with 2 samples
# Processing file anomaly_a244.csv with 1 samples
# Processing file anomaly_a245.csv with 4 samples
# Processing file anomaly_a246.csv with 3 samples
# Skipping file anomaly_a247.csv - too few frames (4 < 5)
# Processing file anomaly_a248.csv with 1 samples
# Processing file anomaly_a249.csv with 3 samples
# Processing file anomaly_a25.csv with 3 samples
# Processing file anomaly_a250.csv with 3 samples
# Processing file anomaly_a251.csv with 3 samples
# Skipping file anomaly_a252.csv - too few frames (4 < 5)
# Processing file anomaly_a253.csv with 1 samples
# Processing file anomaly_a254.csv with 2 samples
# Processing file anomaly_a255.csv with 3 samples
# Processing file anomaly_a256.csv with 5 samples
# Processing file anomaly_a257.csv with 3 samples
# Processing file anomaly_a258.csv with 2 samples
# Processing file anomaly_a259.csv with 3 samples
# Skipping file anomaly_a26.csv - too few frames (4 < 5)
# Processing file anomaly_a260.csv with 3 samples
# Processing file anomaly_a261.csv with 3 samples
# Processing file anomaly_a262.csv with 4 samples
# Processing file anomaly_a263.csv with 3 samples
# Skipping file anomaly_a264.csv - too few frames (4 < 5)
# Processing file anomaly_a265.csv with 3 samples
# Processing file anomaly_a266.csv with 2 samples
# Processing file anomaly_a267.csv with 4 samples
# Processing file anomaly_a268.csv with 3 samples
# Processing file anomaly_a269.csv with 2 samples
# Processing file anomaly_a27.csv with 4 samples
# Processing file anomaly_a270.csv with 4 samples
# Processing file anomaly_a271.csv with 4 samples
# Processing file anomaly_a272.csv with 4 samples
# Skipping file anomaly_a273.csv - too few frames (4 < 5)
# Skipping file anomaly_a274.csv - too few frames (4 < 5)
# Processing file anomaly_a275.csv with 4 samples
# Processing file anomaly_a276.csv with 1 samples
# Processing file anomaly_a277.csv with 3 samples
# Processing file anomaly_a278.csv with 4 samples
# Processing file anomaly_a279.csv with 3 samples
# Processing file anomaly_a28.csv with 3 samples
# Processing file anomaly_a280.csv with 4 samples
# Processing file anomaly_a281.csv with 4 samples
# Skipping file anomaly_a282.csv - too few frames (4 < 5)
# Processing file anomaly_a283.csv with 3 samples
# Processing file anomaly_a284.csv with 3 samples
# Processing file anomaly_a285.csv with 5 samples
# Processing file anomaly_a286.csv with 3 samples
# Processing file anomaly_a287.csv with 3 samples
# Processing file anomaly_a288.csv with 4 samples
# Processing file anomaly_a289.csv with 3 samples
# Processing file anomaly_a29.csv with 3 samples
# Processing file anomaly_a290.csv with 3 samples
# Skipping file anomaly_a291.csv - too few frames (4 < 5)
# Processing file anomaly_a292.csv with 5 samples
# Processing file anomaly_a293.csv with 2 samples
# Processing file anomaly_a294.csv with 2 samples
# Skipping file anomaly_a295.csv - too few frames (4 < 5)
# Processing file anomaly_a296.csv with 3 samples
# Processing file anomaly_a297.csv with 3 samples
# Processing file anomaly_a298.csv with 3 samples
# Processing file anomaly_a299.csv with 4 samples
# Processing file anomaly_a3.csv with 3 samples
# Processing file anomaly_a30.csv with 4 samples
# Processing file anomaly_a300.csv with 3 samples
# Processing file anomaly_a301.csv with 3 samples
# Processing file anomaly_a302.csv with 3 samples
# Skipping file anomaly_a303.csv - too few frames (4 < 5)
# Processing file anomaly_a304.csv with 3 samples
# Processing file anomaly_a305.csv with 5 samples
# Processing file anomaly_a306.csv with 4 samples
# Processing file anomaly_a307.csv with 4 samples
# Processing file anomaly_a308.csv with 4 samples
# Processing file anomaly_a309.csv with 4 samples
# Processing file anomaly_a31.csv with 4 samples
# Processing file anomaly_a310.csv with 3 samples
# Skipping file anomaly_a311.csv - too few frames (4 < 5)
# Processing file anomaly_a312.csv with 3 samples
# Processing file anomaly_a313.csv with 3 samples
# Processing file anomaly_a314.csv with 4 samples
# Processing file anomaly_a315.csv with 3 samples
# Processing file anomaly_a316.csv with 2 samples
# Processing file anomaly_a317.csv with 5 samples
# Processing file anomaly_a318.csv with 2 samples
# Processing file anomaly_a319.csv with 3 samples
# Processing file anomaly_a32.csv with 2 samples
# Skipping file anomaly_a320.csv - too few frames (4 < 5)
# Skipping file anomaly_a321.csv - too few frames (2 < 5)
# Processing file anomaly_a322.csv with 3 samples
# Processing file anomaly_a323.csv with 5 samples
# Processing file anomaly_a324.csv with 1 samples
# Processing file anomaly_a325.csv with 3 samples
# Processing file anomaly_a326.csv with 3 samples
# Processing file anomaly_a327.csv with 3 samples
# Processing file anomaly_a328.csv with 2 samples
# Processing file anomaly_a329.csv with 3 samples
# Processing file anomaly_a33.csv with 5 samples
# Processing file anomaly_a330.csv with 3 samples
# Processing file anomaly_a331.csv with 3 samples
# Processing file anomaly_a332.csv with 1 samples
# Processing file anomaly_a333.csv with 3 samples
# Processing file anomaly_a334.csv with 3 samples
# Processing file anomaly_a335.csv with 4 samples
# Processing file anomaly_a336.csv with 3 samples
# Skipping file anomaly_a337.csv - too few frames (4 < 5)
# Processing file anomaly_a338.csv with 3 samples
# Processing file anomaly_a339.csv with 3 samples
# Processing file anomaly_a34.csv with 1 samples
# Processing file anomaly_a340.csv with 8 samples
# Processing file anomaly_a341.csv with 2 samples
# Processing file anomaly_a342.csv with 5 samples
# Processing file anomaly_a343.csv with 6 samples
# Processing file anomaly_a344.csv with 3 samples
# Processing file anomaly_a345.csv with 5 samples
# Processing file anomaly_a346.csv with 3 samples
# Processing file anomaly_a347.csv with 5 samples
# Processing file anomaly_a348.csv with 4 samples
# Processing file anomaly_a349.csv with 5 samples
# Processing file anomaly_a35.csv with 3 samples
# Processing file anomaly_a350.csv with 2 samples
# Processing file anomaly_a351.csv with 1 samples
# Processing file anomaly_a352.csv with 4 samples
# Processing file anomaly_a353.csv with 4 samples
# Processing file anomaly_a354.csv with 3 samples
# Processing file anomaly_a355.csv with 5 samples
# Processing file anomaly_a356.csv with 3 samples
# Processing file anomaly_a357.csv with 3 samples
# Processing file anomaly_a358.csv with 4 samples
# Processing file anomaly_a359.csv with 4 samples
# Processing file anomaly_a36.csv with 3 samples
# Processing file anomaly_a360.csv with 3 samples
# Processing file anomaly_a361.csv with 4 samples
# Processing file anomaly_a362.csv with 3 samples
# Processing file anomaly_a363.csv with 4 samples
# Processing file anomaly_a364.csv with 3 samples
# Processing file anomaly_a365.csv with 4 samples
# Processing file anomaly_a366.csv with 3 samples
# Skipping file anomaly_a367.csv - too few frames (2 < 5)
# Processing file anomaly_a368.csv with 5 samples
# Processing file anomaly_a369.csv with 2 samples
# Processing file anomaly_a37.csv with 4 samples
# Processing file anomaly_a370.csv with 2 samples
# Processing file anomaly_a371.csv with 2 samples
# Processing file anomaly_a372.csv with 2 samples
# Processing file anomaly_a373.csv with 3 samples
# Processing file anomaly_a374.csv with 3 samples
# Processing file anomaly_a375.csv with 1 samples
# Processing file anomaly_a376.csv with 3 samples
# Processing file anomaly_a377.csv with 3 samples
# Processing file anomaly_a378.csv with 2 samples
# Processing file anomaly_a379.csv with 2 samples
# Processing file anomaly_a38.csv with 2 samples
# Processing file anomaly_a380.csv with 3 samples
# Processing file anomaly_a381.csv with 3 samples
# Processing file anomaly_a382.csv with 5 samples
# Processing file anomaly_a383.csv with 3 samples
# Processing file anomaly_a384.csv with 4 samples
# Processing file anomaly_a385.csv with 3 samples
# Processing file anomaly_a386.csv with 3 samples
# Processing file anomaly_a387.csv with 3 samples
# Processing file anomaly_a388.csv with 3 samples
# Processing file anomaly_a389.csv with 3 samples
# Processing file anomaly_a39.csv with 5 samples
# Processing file anomaly_a390.csv with 3 samples
# Processing file anomaly_a391.csv with 3 samples
# Processing file anomaly_a392.csv with 4 samples
# Skipping file anomaly_a393.csv - too few frames (4 < 5)
# Processing file anomaly_a394.csv with 2 samples
# Processing file anomaly_a395.csv with 5 samples
# Processing file anomaly_a396.csv with 3 samples
# Processing file anomaly_a397.csv with 3 samples
# Processing file anomaly_a398.csv with 3 samples
# Processing file anomaly_a399.csv with 4 samples
# Processing file anomaly_a4.csv with 4 samples
# Processing file anomaly_a40.csv with 5 samples
# Processing file anomaly_a400.csv with 3 samples
# Processing file anomaly_a401.csv with 2 samples
# Processing file anomaly_a402.csv with 3 samples
# Processing file anomaly_a403.csv with 3 samples
# Processing file anomaly_a404.csv with 5 samples
# Processing file anomaly_a405.csv with 3 samples
# Processing file anomaly_a406.csv with 3 samples
# Processing file anomaly_a407.csv with 1 samples
# Processing file anomaly_a408.csv with 2 samples
# Skipping file anomaly_a409.csv - too few frames (2 < 5)
# Processing file anomaly_a41.csv with 6 samples
# Processing file anomaly_a410.csv with 3 samples
# Processing file anomaly_a411.csv with 4 samples
# Processing file anomaly_a412.csv with 3 samples
# Processing file anomaly_a413.csv with 4 samples
# Processing file anomaly_a414.csv with 5 samples
# Processing file anomaly_a415.csv with 2 samples
# Processing file anomaly_a416.csv with 1 samples
# Processing file anomaly_a417.csv with 4 samples
# Skipping file anomaly_a418.csv - too few frames (4 < 5)
# Processing file anomaly_a419.csv with 4 samples
# Processing file anomaly_a42.csv with 3 samples
# Processing file anomaly_a420.csv with 2 samples
# Processing file anomaly_a421.csv with 4 samples
# Processing file anomaly_a422.csv with 3 samples
# Processing file anomaly_a423.csv with 3 samples
# Processing file anomaly_a424.csv with 3 samples
# Skipping file anomaly_a425.csv - too few frames (4 < 5)
# Processing file anomaly_a426.csv with 4 samples
# Processing file anomaly_a427.csv with 3 samples
# Skipping file anomaly_a428.csv - too few frames (3 < 5)
# Processing file anomaly_a429.csv with 2 samples
# Processing file anomaly_a43.csv with 2 samples
# Processing file anomaly_a430.csv with 3 samples
# Processing file anomaly_a431.csv with 2 samples
# Processing file anomaly_a432.csv with 3 samples
# Processing file anomaly_a433.csv with 3 samples
# Processing file anomaly_a434.csv with 3 samples
# Processing file anomaly_a435.csv with 2 samples
# Processing file anomaly_a436.csv with 5 samples
# Processing file anomaly_a437.csv with 2 samples
# Processing file anomaly_a438.csv with 2 samples
# Processing file anomaly_a439.csv with 4 samples
# Processing file anomaly_a44.csv with 3 samples
# Skipping file anomaly_a440.csv - too few frames (4 < 5)
# Processing file anomaly_a441.csv with 3 samples
# Processing file anomaly_a442.csv with 2 samples
# Processing file anomaly_a443.csv with 3 samples
# Skipping file anomaly_a444.csv - too few frames (4 < 5)
# Processing file anomaly_a445.csv with 2 samples
# Processing file anomaly_a446.csv with 4 samples
# Processing file anomaly_a447.csv with 5 samples
# Processing file anomaly_a448.csv with 3 samples
# Processing file anomaly_a449.csv with 3 samples
# Processing file anomaly_a45.csv with 2 samples
# Processing file anomaly_a450.csv with 4 samples
# Skipping file anomaly_a451.csv - too few frames (4 < 5)
# Processing file anomaly_a452.csv with 3 samples
# Processing file anomaly_a453.csv with 5 samples
# Processing file anomaly_a454.csv with 3 samples
# Processing file anomaly_a455.csv with 5 samples
# Processing file anomaly_a456.csv with 3 samples
# Processing file anomaly_a457.csv with 2 samples
# Processing file anomaly_a458.csv with 3 samples
# Processing file anomaly_a459.csv with 3 samples
# Processing file anomaly_a46.csv with 3 samples
# Processing file anomaly_a460.csv with 4 samples
# Processing file anomaly_a461.csv with 3 samples
# Skipping file anomaly_a462.csv - too few frames (4 < 5)
# Processing file anomaly_a463.csv with 2 samples
# Processing file anomaly_a464.csv with 3 samples
# Processing file anomaly_a465.csv with 3 samples
# Processing file anomaly_a466.csv with 2 samples
# Processing file anomaly_a467.csv with 3 samples
# Processing file anomaly_a468.csv with 2 samples
# Processing file anomaly_a469.csv with 4 samples
# Processing file anomaly_a47.csv with 3 samples
# Processing file anomaly_a470.csv with 3 samples
# Processing file anomaly_a471.csv with 3 samples
# Processing file anomaly_a472.csv with 3 samples
# Processing file anomaly_a473.csv with 3 samples
# Processing file anomaly_a474.csv with 4 samples
# Skipping file anomaly_a475.csv - too few frames (4 < 5)
# Processing file anomaly_a476.csv with 4 samples
# Processing file anomaly_a477.csv with 4 samples
# Processing file anomaly_a478.csv with 4 samples
# Processing file anomaly_a479.csv with 2 samples
# Processing file anomaly_a48.csv with 3 samples
# Processing file anomaly_a480.csv with 4 samples
# Processing file anomaly_a481.csv with 4 samples
# Processing file anomaly_a482.csv with 5 samples
# Processing file anomaly_a483.csv with 4 samples
# Processing file anomaly_a484.csv with 3 samples
# Processing file anomaly_a485.csv with 1 samples
# Skipping file anomaly_a486.csv - too few frames (4 < 5)
# Skipping file anomaly_a487.csv - too few frames (4 < 5)
# Processing file anomaly_a488.csv with 3 samples
# Processing file anomaly_a489.csv with 4 samples
# Processing file anomaly_a49.csv with 4 samples
# Processing file anomaly_a490.csv with 1 samples
# Processing file anomaly_a491.csv with 3 samples
# Processing file anomaly_a492.csv with 1 samples
# Processing file anomaly_a493.csv with 4 samples
# Processing file anomaly_a494.csv with 3 samples
# Processing file anomaly_a495.csv with 5 samples
# Processing file anomaly_a496.csv with 5 samples
# Processing file anomaly_a497.csv with 3 samples
# Skipping file anomaly_a498.csv - too few frames (4 < 5)
# Skipping file anomaly_a499.csv - too few frames (4 < 5)
# Processing file anomaly_a5.csv with 3 samples
# Processing file anomaly_a50.csv with 3 samples
# Processing file anomaly_a500.csv with 2 samples
# Processing file anomaly_a501.csv with 5 samples
# Processing file anomaly_a502.csv with 3 samples
# Processing file anomaly_a503.csv with 3 samples
# Skipping file anomaly_a504.csv - too few frames (4 < 5)
# Processing file anomaly_a505.csv with 5 samples
# Processing file anomaly_a506.csv with 2 samples
# Processing file anomaly_a507.csv with 5 samples
# Skipping file anomaly_a508.csv - too few frames (4 < 5)
# Processing file anomaly_a509.csv with 3 samples
# Processing file anomaly_a51.csv with 2 samples
# Processing file anomaly_a510.csv with 3 samples
# Processing file anomaly_a511.csv with 4 samples
# Processing file anomaly_a512.csv with 5 samples
# Processing file anomaly_a513.csv with 1 samples
# Processing file anomaly_a514.csv with 5 samples
# Skipping file anomaly_a515.csv - too few frames (4 < 5)
# Processing file anomaly_a516.csv with 2 samples
# Processing file anomaly_a517.csv with 5 samples
# Processing file anomaly_a518.csv with 4 samples
# Processing file anomaly_a519.csv with 6 samples
# Processing file anomaly_a52.csv with 5 samples
# Processing file anomaly_a520.csv with 3 samples
# Processing file anomaly_a521.csv with 4 samples
# Processing file anomaly_a522.csv with 3 samples
# Processing file anomaly_a523.csv with 3 samples
# Processing file anomaly_a524.csv with 4 samples
# Processing file anomaly_a525.csv with 3 samples
# Processing file anomaly_a526.csv with 2 samples
# Processing file anomaly_a527.csv with 5 samples
# Processing file anomaly_a528.csv with 3 samples
# Processing file anomaly_a529.csv with 3 samples
# Processing file anomaly_a53.csv with 2 samples
# Processing file anomaly_a530.csv with 3 samples
# Processing file anomaly_a531.csv with 3 samples
# Processing file anomaly_a532.csv with 3 samples
# Processing file anomaly_a533.csv with 2 samples
# Processing file anomaly_a534.csv with 2 samples
# Processing file anomaly_a535.csv with 4 samples
# Processing file anomaly_a536.csv with 3 samples
# Processing file anomaly_a537.csv with 3 samples
# Processing file anomaly_a538.csv with 3 samples
# Processing file anomaly_a539.csv with 2 samples
# Processing file anomaly_a54.csv with 3 samples
# Skipping file anomaly_a540.csv - too few frames (4 < 5)
# Skipping file anomaly_a541.csv - too few frames (4 < 5)
# Processing file anomaly_a542.csv with 3 samples
# Processing file anomaly_a543.csv with 3 samples
# Processing file anomaly_a544.csv with 2 samples
# Processing file anomaly_a545.csv with 5 samples
# Processing file anomaly_a546.csv with 2 samples
# Processing file anomaly_a547.csv with 3 samples
# Processing file anomaly_a548.csv with 2 samples
# Processing file anomaly_a549.csv with 3 samples
# Processing file anomaly_a55.csv with 3 samples
# Processing file anomaly_a550.csv with 3 samples
# Processing file anomaly_a551.csv with 3 samples
# Processing file anomaly_a552.csv with 3 samples
# Processing file anomaly_a553.csv with 2 samples
# Processing file anomaly_a554.csv with 5 samples
# Processing file anomaly_a555.csv with 4 samples
# Skipping file anomaly_a556.csv - too few frames (4 < 5)
# Processing file anomaly_a557.csv with 3 samples
# Processing file anomaly_a558.csv with 4 samples
# Processing file anomaly_a559.csv with 3 samples
# Processing file anomaly_a56.csv with 3 samples
# Processing file anomaly_a560.csv with 2 samples
# Processing file anomaly_a561.csv with 4 samples
# Processing file anomaly_a562.csv with 4 samples
# Processing file anomaly_a563.csv with 2 samples
# Processing file anomaly_a564.csv with 2 samples
# Skipping file anomaly_a565.csv - too few frames (4 < 5)
# Skipping file anomaly_a566.csv - too few frames (4 < 5)
# Processing file anomaly_a567.csv with 4 samples
# Processing file anomaly_a568.csv with 3 samples
# Processing file anomaly_a569.csv with 3 samples
# Processing file anomaly_a57.csv with 5 samples
# Processing file anomaly_a570.csv with 2 samples
# Processing file anomaly_a571.csv with 2 samples
# Processing file anomaly_a572.csv with 2 samples
# Processing file anomaly_a573.csv with 2 samples
# Processing file anomaly_a574.csv with 3 samples
# Processing file anomaly_a575.csv with 5 samples
# Processing file anomaly_a576.csv with 1 samples
# Processing file anomaly_a577.csv with 4 samples
# Processing file anomaly_a578.csv with 3 samples
# Processing file anomaly_a579.csv with 2 samples
# Processing file anomaly_a58.csv with 3 samples
# Processing file anomaly_a580.csv with 2 samples
# Processing file anomaly_a581.csv with 3 samples
# Processing file anomaly_a582.csv with 1 samples
# Processing file anomaly_a583.csv with 5 samples
# Processing file anomaly_a584.csv with 2 samples
# Processing file anomaly_a585.csv with 4 samples
# Processing file anomaly_a586.csv with 2 samples
# Processing file anomaly_a587.csv with 5 samples
# Processing file anomaly_a588.csv with 2 samples
# Processing file anomaly_a589.csv with 3 samples
# Processing file anomaly_a59.csv with 374 samples
# Processing file anomaly_a590.csv with 3 samples
# Processing file anomaly_a591.csv with 3 samples
# Processing file anomaly_a592.csv with 4 samples
# Processing file anomaly_a593.csv with 1 samples
# Processing file anomaly_a594.csv with 3 samples
# Processing file anomaly_a595.csv with 3 samples
# Processing file anomaly_a596.csv with 4 samples
# Processing file anomaly_a597.csv with 3 samples
# Processing file anomaly_a598.csv with 5 samples
# Processing file anomaly_a599.csv with 2 samples
# Processing file anomaly_a6.csv with 3 samples
# Processing file anomaly_a60.csv with 3 samples
# Processing file anomaly_a600.csv with 3 samples
# Processing file anomaly_a601.csv with 1 samples
# Processing file anomaly_a602.csv with 3 samples
# Processing file anomaly_a603.csv with 3 samples
# Processing file anomaly_a604.csv with 3 samples
# Processing file anomaly_a605.csv with 3 samples
# Processing file anomaly_a606.csv with 4 samples
# Processing file anomaly_a607.csv with 3 samples
# Processing file anomaly_a608.csv with 3 samples
# Processing file anomaly_a609.csv with 3 samples
# Processing file anomaly_a61.csv with 2 samples
# Processing file anomaly_a610.csv with 3 samples
# Processing file anomaly_a611.csv with 3 samples
# Processing file anomaly_a612.csv with 2 samples
# Processing file anomaly_a613.csv with 4 samples
# Processing file anomaly_a614.csv with 2 samples
# Processing file anomaly_a615.csv with 3 samples
# Skipping file anomaly_a616.csv - too few frames (4 < 5)
# Processing file anomaly_a617.csv with 5 samples
# Processing file anomaly_a618.csv with 3 samples
# Processing file anomaly_a619.csv with 4 samples
# Processing file anomaly_a62.csv with 3 samples
# Processing file anomaly_a620.csv with 4 samples
# Processing file anomaly_a621.csv with 3 samples
# Processing file anomaly_a622.csv with 4 samples
# Processing file anomaly_a623.csv with 5 samples
# Processing file anomaly_a624.csv with 4 samples
# Processing file anomaly_a625.csv with 3 samples
# Skipping file anomaly_a626.csv - too few frames (4 < 5)
# Processing file anomaly_a627.csv with 4 samples
# Processing file anomaly_a628.csv with 4 samples
# Processing file anomaly_a629.csv with 4 samples
# Processing file anomaly_a63.csv with 3 samples
# Processing file anomaly_a630.csv with 4 samples
# Processing file anomaly_a631.csv with 3 samples
# Skipping file anomaly_a632.csv - too few frames (4 < 5)
# Skipping file anomaly_a633.csv - too few frames (4 < 5)
# Processing file anomaly_a634.csv with 3 samples
# Processing file anomaly_a635.csv with 2 samples
# Processing file anomaly_a636.csv with 2 samples
# Processing file anomaly_a637.csv with 3 samples
# Processing file anomaly_a638.csv with 3 samples
# Skipping file anomaly_a639.csv - too few frames (4 < 5)
# Processing file anomaly_a64.csv with 3 samples
# Processing file anomaly_a640.csv with 4 samples
# Processing file anomaly_a641.csv with 3 samples
# Processing file anomaly_a642.csv with 3 samples
# Processing file anomaly_a643.csv with 2 samples
# Processing file anomaly_a644.csv with 3 samples
# Processing file anomaly_a645.csv with 4 samples
# Processing file anomaly_a646.csv with 3 samples
# Processing file anomaly_a647.csv with 5 samples
# Processing file anomaly_a648.csv with 3 samples
# Processing file anomaly_a649.csv with 3 samples
# Processing file anomaly_a65.csv with 3 samples
# Processing file anomaly_a650.csv with 2 samples
# Processing file anomaly_a651.csv with 2 samples
# Processing file anomaly_a652.csv with 2 samples
# Processing file anomaly_a653.csv with 3 samples
# Processing file anomaly_a654.csv with 4 samples
# Processing file anomaly_a655.csv with 3 samples
# Processing file anomaly_a656.csv with 2 samples
# Processing file anomaly_a657.csv with 3 samples
# Processing file anomaly_a658.csv with 4 samples
# Processing file anomaly_a659.csv with 4 samples
# Processing file anomaly_a66.csv with 3 samples
# Processing file anomaly_a660.csv with 3 samples
# Processing file anomaly_a661.csv with 3 samples
# Processing file anomaly_a662.csv with 4 samples
# Processing file anomaly_a663.csv with 3 samples
# Processing file anomaly_a664.csv with 4 samples
# Processing file anomaly_a665.csv with 4 samples
# Processing file anomaly_a666.csv with 3 samples
# Processing file anomaly_a667.csv with 3 samples
# Processing file anomaly_a668.csv with 4 samples
# Processing file anomaly_a669.csv with 3 samples
# Skipping file anomaly_a67.csv - too few frames (2 < 5)
# Skipping file anomaly_a670.csv - too few frames (4 < 5)
# Processing file anomaly_a671.csv with 3 samples
# Processing file anomaly_a672.csv with 5 samples
# Processing file anomaly_a673.csv with 2 samples
# Processing file anomaly_a674.csv with 2 samples
# Skipping file anomaly_a675.csv - too few frames (4 < 5)
# Processing file anomaly_a676.csv with 5 samples
# Processing file anomaly_a677.csv with 135 samples
# Processing file anomaly_a678.csv with 3 samples
# Processing file anomaly_a679.csv with 3 samples
# Processing file anomaly_a68.csv with 4 samples
# Processing file anomaly_a680.csv with 3 samples
# Processing file anomaly_a681.csv with 4 samples
# Processing file anomaly_a682.csv with 3 samples
# Processing file anomaly_a683.csv with 4 samples
# Processing file anomaly_a684.csv with 3 samples
# Processing file anomaly_a685.csv with 2 samples
# Processing file anomaly_a686.csv with 3 samples
# Processing file anomaly_a687.csv with 4 samples
# Skipping file anomaly_a688.csv - too few frames (4 < 5)
# Processing file anomaly_a689.csv with 3 samples
# Processing file anomaly_a69.csv with 3 samples
# Processing file anomaly_a7.csv with 4 samples
# Processing file anomaly_a70.csv with 3 samples
# Processing file anomaly_a71.csv with 3 samples
# Processing file anomaly_a72.csv with 4 samples
# Processing file anomaly_a73.csv with 5 samples
# Processing file anomaly_a74.csv with 3 samples
# Processing file anomaly_a75.csv with 3 samples
# Processing file anomaly_a76.csv with 4 samples
# Processing file anomaly_a77.csv with 4 samples
# Processing file anomaly_a78.csv with 4 samples
# Processing file anomaly_a79.csv with 3 samples
# Processing file anomaly_a8.csv with 3 samples
# Processing file anomaly_a80.csv with 3 samples
# Processing file anomaly_a81.csv with 1 samples
# Processing file anomaly_a82.csv with 2 samples
# Processing file anomaly_a83.csv with 2 samples
# Processing file anomaly_a84.csv with 3 samples
# Processing file anomaly_a85.csv with 4 samples
# Processing file anomaly_a86.csv with 2 samples
# Processing file anomaly_a87.csv with 3 samples
# Processing file anomaly_a88.csv with 3 samples
# Skipping file anomaly_a89.csv - too few frames (4 < 5)
# Processing file anomaly_a9.csv with 5 samples
# Processing file anomaly_a90.csv with 4 samples
# Processing file anomaly_a91.csv with 3 samples
# Skipping file anomaly_a92.csv - too few frames (4 < 5)
# Processing file anomaly_a93.csv with 2 samples
# Processing file anomaly_a94.csv with 3 samples
# Processing file anomaly_a95.csv with 3 samples
# Processing file anomaly_a96.csv with 5 samples
# Processing file anomaly_a97.csv with 4 samples
# Processing file anomaly_a98.csv with 3 samples
# Processing file anomaly_a99.csv with 3 samples
# Processing file nonanomaly_a0.csv with 3 samples
# Processing file nonanomaly_a1.csv with 3 samples
# Processing file nonanomaly_a10.csv with 3 samples
# Processing file nonanomaly_a100.csv with 3 samples
# Skipping file nonanomaly_a101.csv - too few frames (4 < 5)
# Processing file nonanomaly_a102.csv with 2 samples
# Processing file nonanomaly_a103.csv with 2 samples
# Processing file nonanomaly_a104.csv with 3 samples
# Processing file nonanomaly_a105.csv with 3 samples
# Processing file nonanomaly_a106.csv with 2 samples
# Processing file nonanomaly_a107.csv with 3 samples
# Processing file nonanomaly_a108.csv with 3 samples
# Processing file nonanomaly_a109.csv with 2 samples
# Skipping file nonanomaly_a11.csv - too few frames (4 < 5)
# Processing file nonanomaly_a110.csv with 2 samples
# Processing file nonanomaly_a111.csv with 2 samples
# Processing file nonanomaly_a112.csv with 4 samples
# Processing file nonanomaly_a113.csv with 3 samples
# Processing file nonanomaly_a114.csv with 3 samples
# Processing file nonanomaly_a115.csv with 3 samples
# Skipping file nonanomaly_a116.csv - too few frames (4 < 5)
# Processing file nonanomaly_a117.csv with 2 samples
# Processing file nonanomaly_a118.csv with 3 samples
# Processing file nonanomaly_a119.csv with 3 samples
# Processing file nonanomaly_a12.csv with 2 samples
# Processing file nonanomaly_a120.csv with 3 samples
# Skipping file nonanomaly_a121.csv - too few frames (4 < 5)
# Processing file nonanomaly_a122.csv with 3 samples
# Processing file nonanomaly_a123.csv with 3 samples
# Processing file nonanomaly_a124.csv with 2 samples
# Processing file nonanomaly_a125.csv with 2 samples
# Processing file nonanomaly_a126.csv with 3 samples
# Processing file nonanomaly_a127.csv with 3 samples
# Skipping file nonanomaly_a128.csv - too few frames (4 < 5)
# Processing file nonanomaly_a129.csv with 3 samples
# Processing file nonanomaly_a13.csv with 3 samples
# Skipping file nonanomaly_a130.csv - too few frames (4 < 5)
# Processing file nonanomaly_a131.csv with 3 samples
# Processing file nonanomaly_a132.csv with 3 samples
# Processing file nonanomaly_a133.csv with 3 samples
# Processing file nonanomaly_a134.csv with 3 samples
# Processing file nonanomaly_a135.csv with 3 samples
# Skipping file nonanomaly_a136.csv - too few frames (4 < 5)
# Processing file nonanomaly_a137.csv with 2 samples
# Processing file nonanomaly_a138.csv with 2 samples
# Skipping file nonanomaly_a139.csv - too few frames (4 < 5)
# Processing file nonanomaly_a14.csv with 3 samples
# Processing file nonanomaly_a140.csv with 3 samples
# Processing file nonanomaly_a141.csv with 2 samples
# Processing file nonanomaly_a142.csv with 3 samples
# Processing file nonanomaly_a143.csv with 3 samples
# Processing file nonanomaly_a144.csv with 2 samples
# Processing file nonanomaly_a145.csv with 3 samples
# Processing file nonanomaly_a146.csv with 3 samples
# Processing file nonanomaly_a147.csv with 3 samples
# Processing file nonanomaly_a148.csv with 2 samples
# Processing file nonanomaly_a149.csv with 3 samples
# Processing file nonanomaly_a15.csv with 3 samples
# Processing file nonanomaly_a150.csv with 3 samples
# Processing file nonanomaly_a151.csv with 2 samples
# Processing file nonanomaly_a152.csv with 2 samples
# Processing file nonanomaly_a153.csv with 2 samples
# Skipping file nonanomaly_a154.csv - too few frames (4 < 5)
# Processing file nonanomaly_a155.csv with 3 samples
# Processing file nonanomaly_a156.csv with 3 samples
# Processing file nonanomaly_a157.csv with 3 samples
# Processing file nonanomaly_a158.csv with 3 samples
# Processing file nonanomaly_a159.csv with 3 samples
# Processing file nonanomaly_a16.csv with 3 samples
# Processing file nonanomaly_a160.csv with 3 samples
# Processing file nonanomaly_a161.csv with 3 samples
# Processing file nonanomaly_a162.csv with 2 samples
# Processing file nonanomaly_a163.csv with 2 samples
# Processing file nonanomaly_a164.csv with 3 samples
# Skipping file nonanomaly_a165.csv - too few frames (4 < 5)
# Processing file nonanomaly_a166.csv with 3 samples
# Processing file nonanomaly_a167.csv with 3 samples
# Processing file nonanomaly_a168.csv with 3 samples
# Processing file nonanomaly_a169.csv with 2 samples
# Processing file nonanomaly_a17.csv with 3 samples
# Processing file nonanomaly_a170.csv with 3 samples
# Processing file nonanomaly_a171.csv with 3 samples
# Processing file nonanomaly_a172.csv with 1 samples
# Skipping file nonanomaly_a173.csv - too few frames (3 < 5)
# Processing file nonanomaly_a174.csv with 3 samples
# Processing file nonanomaly_a175.csv with 3 samples
# Skipping file nonanomaly_a176.csv - too few frames (3 < 5)
# Processing file nonanomaly_a177.csv with 2 samples
# Processing file nonanomaly_a178.csv with 2 samples
# Processing file nonanomaly_a179.csv with 2 samples
# Skipping file nonanomaly_a18.csv - too few frames (4 < 5)
# Processing file nonanomaly_a180.csv with 3 samples
# Processing file nonanomaly_a181.csv with 2 samples
# Processing file nonanomaly_a182.csv with 3 samples
# Skipping file nonanomaly_a183.csv - too few frames (4 < 5)
# Processing file nonanomaly_a184.csv with 3 samples
# Processing file nonanomaly_a185.csv with 3 samples
# Processing file nonanomaly_a186.csv with 3 samples
# Processing file nonanomaly_a187.csv with 3 samples
# Skipping file nonanomaly_a188.csv - too few frames (4 < 5)
# Processing file nonanomaly_a189.csv with 3 samples
# Processing file nonanomaly_a19.csv with 3 samples
# Skipping file nonanomaly_a190.csv - too few frames (4 < 5)
# Processing file nonanomaly_a191.csv with 2 samples
# Skipping file nonanomaly_a192.csv - too few frames (4 < 5)
# Processing file nonanomaly_a193.csv with 3 samples
# Skipping file nonanomaly_a194.csv - too few frames (4 < 5)
# Processing file nonanomaly_a195.csv with 3 samples
# Skipping file nonanomaly_a196.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a197.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a198.csv - too few frames (4 < 5)
# Processing file nonanomaly_a199.csv with 3 samples
# Skipping file nonanomaly_a2.csv - too few frames (4 < 5)
# Processing file nonanomaly_a20.csv with 2 samples
# Processing file nonanomaly_a200.csv with 4 samples
# Processing file nonanomaly_a201.csv with 2 samples
# Skipping file nonanomaly_a202.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a203.csv - too few frames (4 < 5)
# Processing file nonanomaly_a204.csv with 3 samples
# Processing file nonanomaly_a205.csv with 2 samples
# Processing file nonanomaly_a206.csv with 4 samples
# Processing file nonanomaly_a207.csv with 3 samples
# Skipping file nonanomaly_a208.csv - too few frames (4 < 5)
# Processing file nonanomaly_a209.csv with 2 samples
# Skipping file nonanomaly_a21.csv - too few frames (3 < 5)
# Processing file nonanomaly_a210.csv with 3 samples
# Processing file nonanomaly_a211.csv with 2 samples
# Processing file nonanomaly_a212.csv with 3 samples
# Processing file nonanomaly_a213.csv with 3 samples
# Processing file nonanomaly_a214.csv with 3 samples
# Processing file nonanomaly_a215.csv with 3 samples
# Processing file nonanomaly_a216.csv with 3 samples
# Processing file nonanomaly_a217.csv with 3 samples
# Processing file nonanomaly_a218.csv with 3 samples
# Processing file nonanomaly_a219.csv with 3 samples
# Processing file nonanomaly_a22.csv with 2 samples
# Processing file nonanomaly_a220.csv with 3 samples
# Processing file nonanomaly_a221.csv with 2 samples
# Processing file nonanomaly_a222.csv with 1 samples
# Skipping file nonanomaly_a223.csv - too few frames (4 < 5)
# Processing file nonanomaly_a224.csv with 3 samples
# Skipping file nonanomaly_a225.csv - too few frames (2 < 5)
# Processing file nonanomaly_a226.csv with 3 samples
# Processing file nonanomaly_a227.csv with 2 samples
# Skipping file nonanomaly_a228.csv - too few frames (4 < 5)
# Processing file nonanomaly_a229.csv with 2 samples
# Processing file nonanomaly_a23.csv with 4 samples
# Processing file nonanomaly_a230.csv with 4 samples
# Skipping file nonanomaly_a231.csv - too few frames (4 < 5)
# Processing file nonanomaly_a232.csv with 3 samples
# Processing file nonanomaly_a233.csv with 3 samples
# Processing file nonanomaly_a234.csv with 2 samples
# Processing file nonanomaly_a235.csv with 2 samples
# Processing file nonanomaly_a236.csv with 3 samples
# Processing file nonanomaly_a237.csv with 2 samples
# Processing file nonanomaly_a238.csv with 3 samples
# Processing file nonanomaly_a239.csv with 3 samples
# Processing file nonanomaly_a24.csv with 2 samples
# Skipping file nonanomaly_a240.csv - too few frames (4 < 5)
# Processing file nonanomaly_a241.csv with 3 samples
# Processing file nonanomaly_a242.csv with 3 samples
# Skipping file nonanomaly_a243.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a244.csv - too few frames (4 < 5)
# Processing file nonanomaly_a245.csv with 3 samples
# Processing file nonanomaly_a246.csv with 3 samples
# Processing file nonanomaly_a247.csv with 4 samples
# Processing file nonanomaly_a248.csv with 2 samples
# Processing file nonanomaly_a249.csv with 3 samples
# Skipping file nonanomaly_a25.csv - too few frames (4 < 5)
# Processing file nonanomaly_a250.csv with 3 samples
# Processing file nonanomaly_a251.csv with 1 samples
# Processing file nonanomaly_a252.csv with 2 samples
# Processing file nonanomaly_a253.csv with 2 samples
# Processing file nonanomaly_a254.csv with 3 samples
# Processing file nonanomaly_a255.csv with 2 samples
# Processing file nonanomaly_a256.csv with 2 samples
# Skipping file nonanomaly_a257.csv - too few frames (4 < 5)
# Processing file nonanomaly_a258.csv with 3 samples
# Skipping file nonanomaly_a259.csv - too few frames (4 < 5)
# Processing file nonanomaly_a26.csv with 1 samples
# Processing file nonanomaly_a260.csv with 2 samples
# Skipping file nonanomaly_a261.csv - too few frames (4 < 5)
# Processing file nonanomaly_a262.csv with 4 samples
# Processing file nonanomaly_a263.csv with 2 samples
# Processing file nonanomaly_a264.csv with 3 samples
# Skipping file nonanomaly_a265.csv - too few frames (4 < 5)
# Processing file nonanomaly_a266.csv with 3 samples
# Skipping file nonanomaly_a267.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a268.csv - too few frames (3 < 5)
# Processing file nonanomaly_a269.csv with 3 samples
# Processing file nonanomaly_a27.csv with 2 samples
# Processing file nonanomaly_a270.csv with 3 samples
# Processing file nonanomaly_a271.csv with 1 samples
# Processing file nonanomaly_a272.csv with 3 samples
# Skipping file nonanomaly_a273.csv - too few frames (4 < 5)
# Processing file nonanomaly_a274.csv with 3 samples
# Skipping file nonanomaly_a275.csv - too few frames (4 < 5)
# Processing file nonanomaly_a276.csv with 3 samples
# Processing file nonanomaly_a277.csv with 3 samples
# Processing file nonanomaly_a278.csv with 2 samples
# Skipping file nonanomaly_a279.csv - too few frames (3 < 5)
# Processing file nonanomaly_a28.csv with 2 samples
# Skipping file nonanomaly_a280.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a281.csv - too few frames (4 < 5)
# Processing file nonanomaly_a282.csv with 2 samples
# Processing file nonanomaly_a283.csv with 3 samples
# Skipping file nonanomaly_a284.csv - too few frames (4 < 5)
# Processing file nonanomaly_a285.csv with 2 samples
# Processing file nonanomaly_a286.csv with 2 samples
# Skipping file nonanomaly_a287.csv - too few frames (4 < 5)
# Processing file nonanomaly_a288.csv with 3 samples
# Processing file nonanomaly_a289.csv with 3 samples
# Processing file nonanomaly_a29.csv with 3 samples
# Processing file nonanomaly_a290.csv with 1 samples
# Processing file nonanomaly_a291.csv with 3 samples
# Processing file nonanomaly_a292.csv with 2 samples
# Processing file nonanomaly_a293.csv with 2 samples
# Processing file nonanomaly_a294.csv with 3 samples
# Processing file nonanomaly_a295.csv with 3 samples
# Processing file nonanomaly_a296.csv with 3 samples
# Processing file nonanomaly_a297.csv with 3 samples
# Skipping file nonanomaly_a298.csv - too few frames (4 < 5)
# Processing file nonanomaly_a299.csv with 3 samples
# Processing file nonanomaly_a3.csv with 2 samples
# Processing file nonanomaly_a30.csv with 3 samples
# Processing file nonanomaly_a300.csv with 3 samples
# Processing file nonanomaly_a301.csv with 3 samples
# Processing file nonanomaly_a302.csv with 3 samples
# Skipping file nonanomaly_a303.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a304.csv - too few frames (4 < 5)
# Processing file nonanomaly_a305.csv with 3 samples
# Processing file nonanomaly_a306.csv with 3 samples
# Processing file nonanomaly_a307.csv with 2 samples
# Processing file nonanomaly_a308.csv with 3 samples
# Processing file nonanomaly_a309.csv with 3 samples
# Processing file nonanomaly_a31.csv with 1 samples
# Processing file nonanomaly_a310.csv with 3 samples
# Processing file nonanomaly_a311.csv with 3 samples
# Processing file nonanomaly_a312.csv with 3 samples
# Processing file nonanomaly_a313.csv with 2 samples
# Skipping file nonanomaly_a314.csv - too few frames (3 < 5)
# Processing file nonanomaly_a315.csv with 3 samples
# Processing file nonanomaly_a316.csv with 3 samples
# Processing file nonanomaly_a317.csv with 3 samples
# Skipping file nonanomaly_a318.csv - too few frames (4 < 5)
# Processing file nonanomaly_a319.csv with 3 samples
# Processing file nonanomaly_a32.csv with 1 samples
# Processing file nonanomaly_a320.csv with 3 samples
# Processing file nonanomaly_a321.csv with 2 samples
# Processing file nonanomaly_a322.csv with 3 samples
# Processing file nonanomaly_a323.csv with 2 samples
# Processing file nonanomaly_a324.csv with 3 samples
# Processing file nonanomaly_a325.csv with 1 samples
# Processing file nonanomaly_a326.csv with 3 samples
# Processing file nonanomaly_a327.csv with 2 samples
# Processing file nonanomaly_a328.csv with 2 samples
# Processing file nonanomaly_a329.csv with 3 samples
# Skipping file nonanomaly_a33.csv - too few frames (3 < 5)
# Processing file nonanomaly_a330.csv with 1 samples
# Processing file nonanomaly_a331.csv with 3 samples
# Processing file nonanomaly_a332.csv with 3 samples
# Processing file nonanomaly_a333.csv with 3 samples
# Processing file nonanomaly_a334.csv with 2 samples
# Processing file nonanomaly_a335.csv with 3 samples
# Skipping file nonanomaly_a336.csv - too few frames (2 < 5)
# Processing file nonanomaly_a337.csv with 2 samples
# Processing file nonanomaly_a338.csv with 3 samples
# Processing file nonanomaly_a339.csv with 3 samples
# Processing file nonanomaly_a34.csv with 1 samples
# Processing file nonanomaly_a340.csv with 3 samples
# Processing file nonanomaly_a341.csv with 3 samples
# Processing file nonanomaly_a342.csv with 3 samples
# Processing file nonanomaly_a343.csv with 3 samples
# Processing file nonanomaly_a344.csv with 3 samples
# Processing file nonanomaly_a345.csv with 2 samples
# ...
# Processing file nonanomaly_a220.csv with 2 samples
# Processing file nonanomaly_a221.csv with 3 samples
# Skipping file nonanomaly_a222.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a223.csv - too few frames (4 < 5)
# Processing file nonanomaly_a224.csv with 3 samples
# Processing file nonanomaly_a225.csv with 3 samples
# Processing file nonanomaly_a226.csv with 3 samples
# Processing file nonanomaly_a227.csv with 2 samples
# Processing file nonanomaly_a228.csv with 2 samples
# Processing file nonanomaly_a229.csv with 3 samples
# Processing file nonanomaly_a23.csv with 3 samples
# Processing file nonanomaly_a230.csv with 3 samples
# Processing file nonanomaly_a231.csv with 3 samples
# Processing file nonanomaly_a232.csv with 3 samples
# Skipping file nonanomaly_a233.csv - too few frames (4 < 5)
# Processing file nonanomaly_a234.csv with 3 samples
# Processing file nonanomaly_a235.csv with 2 samples
# Processing file nonanomaly_a236.csv with 3 samples
# Processing file nonanomaly_a237.csv with 3 samples
# Processing file nonanomaly_a238.csv with 2 samples
# Processing file nonanomaly_a239.csv with 2 samples
# Processing file nonanomaly_a24.csv with 3 samples
# Processing file nonanomaly_a240.csv with 3 samples
# Processing file nonanomaly_a241.csv with 4 samples
# Processing file nonanomaly_a242.csv with 2 samples
# Processing file nonanomaly_a243.csv with 2 samples
# Processing file nonanomaly_a244.csv with 3 samples
# Processing file nonanomaly_a245.csv with 3 samples
# Processing file nonanomaly_a246.csv with 2 samples
# Processing file nonanomaly_a247.csv with 3 samples
# Processing file nonanomaly_a248.csv with 2 samples
# Processing file nonanomaly_a249.csv with 3 samples
# Processing file nonanomaly_a25.csv with 3 samples
# Processing file nonanomaly_a250.csv with 3 samples
# Processing file nonanomaly_a251.csv with 3 samples
# Skipping file nonanomaly_a252.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a253.csv - too few frames (4 < 5)
# Processing file nonanomaly_a254.csv with 2 samples
# Processing file nonanomaly_a255.csv with 3 samples
# Skipping file nonanomaly_a256.csv - too few frames (4 < 5)
# Processing file nonanomaly_a257.csv with 2 samples
# Skipping file nonanomaly_a258.csv - too few frames (4 < 5)
# Processing file nonanomaly_a259.csv with 3 samples
# Processing file nonanomaly_a26.csv with 3 samples
# Processing file nonanomaly_a260.csv with 4 samples
# Processing file nonanomaly_a261.csv with 3 samples
# Processing file nonanomaly_a262.csv with 2 samples
# Skipping file nonanomaly_a263.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a264.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a265.csv - too few frames (4 < 5)
# Processing file nonanomaly_a266.csv with 3 samples
# Skipping file nonanomaly_a267.csv - too few frames (4 < 5)
# Processing file nonanomaly_a268.csv with 1 samples
# Processing file nonanomaly_a269.csv with 2 samples
# Processing file nonanomaly_a27.csv with 4 samples
# Processing file nonanomaly_a270.csv with 3 samples
# Processing file nonanomaly_a271.csv with 2 samples
# Processing file nonanomaly_a272.csv with 2 samples
# Processing file nonanomaly_a273.csv with 3 samples
# Processing file nonanomaly_a274.csv with 3 samples
# Processing file nonanomaly_a275.csv with 3 samples
# Processing file nonanomaly_a276.csv with 3 samples
# Processing file nonanomaly_a277.csv with 3 samples
# Processing file nonanomaly_a278.csv with 3 samples
# Skipping file nonanomaly_a279.csv - too few frames (4 < 5)
# Processing file nonanomaly_a28.csv with 1 samples
# Processing file nonanomaly_a280.csv with 3 samples
# Processing file nonanomaly_a281.csv with 2 samples
# Processing file nonanomaly_a282.csv with 3 samples
# Processing file nonanomaly_a283.csv with 2 samples
# Processing file nonanomaly_a284.csv with 2 samples
# Processing file nonanomaly_a285.csv with 2 samples
# Processing file nonanomaly_a286.csv with 2 samples
# Skipping file nonanomaly_a287.csv - too few frames (4 < 5)
# Processing file nonanomaly_a288.csv with 3 samples
# Processing file nonanomaly_a289.csv with 2 samples
# Processing file nonanomaly_a29.csv with 3 samples
# Skipping file nonanomaly_a290.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a291.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a292.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a293.csv - too few frames (4 < 5)
# Processing file nonanomaly_a294.csv with 3 samples
# Processing file nonanomaly_a295.csv with 2 samples
# Processing file nonanomaly_a296.csv with 3 samples
# Processing file nonanomaly_a297.csv with 3 samples
# Processing file nonanomaly_a298.csv with 3 samples
# Skipping file nonanomaly_a299.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a3.csv - too few frames (3 < 5)
# Processing file nonanomaly_a30.csv with 3 samples
# Processing file nonanomaly_a300.csv with 2 samples
# Processing file nonanomaly_a301.csv with 2 samples
# Processing file nonanomaly_a302.csv with 3 samples
# Processing file nonanomaly_a303.csv with 2 samples
# Processing file nonanomaly_a304.csv with 2 samples
# Processing file nonanomaly_a305.csv with 2 samples
# Processing file nonanomaly_a306.csv with 2 samples
# Processing file nonanomaly_a307.csv with 3 samples
# Processing file nonanomaly_a308.csv with 3 samples
# Processing file nonanomaly_a309.csv with 3 samples
# Processing file nonanomaly_a31.csv with 2 samples
# Processing file nonanomaly_a310.csv with 2 samples
# Skipping file nonanomaly_a311.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a312.csv - too few frames (4 < 5)
# Processing file nonanomaly_a313.csv with 2 samples
# Skipping file nonanomaly_a314.csv - too few frames (3 < 5)
# Processing file nonanomaly_a315.csv with 3 samples
# Processing file nonanomaly_a316.csv with 3 samples
# Processing file nonanomaly_a317.csv with 2 samples
# Skipping file nonanomaly_a318.csv - too few frames (4 < 5)
# Processing file nonanomaly_a319.csv with 3 samples
# Processing file nonanomaly_a32.csv with 3 samples
# Processing file nonanomaly_a320.csv with 3 samples
# Processing file nonanomaly_a321.csv with 5 samples
# Processing file nonanomaly_a322.csv with 3 samples
# Processing file nonanomaly_a323.csv with 3 samples
# Processing file nonanomaly_a324.csv with 2 samples
# Processing file nonanomaly_a325.csv with 2 samples
# Processing file nonanomaly_a326.csv with 3 samples
# Processing file nonanomaly_a327.csv with 3 samples
# Processing file nonanomaly_a328.csv with 3 samples
# Skipping file nonanomaly_a329.csv - too few frames (4 < 5)
# Processing file nonanomaly_a33.csv with 2 samples
# Processing file nonanomaly_a330.csv with 3 samples
# Skipping file nonanomaly_a331.csv - too few frames (4 < 5)
# Processing file nonanomaly_a332.csv with 2 samples
# Processing file nonanomaly_a333.csv with 3 samples
# Processing file nonanomaly_a334.csv with 3 samples
# Processing file nonanomaly_a335.csv with 3 samples
# Processing file nonanomaly_a336.csv with 3 samples
# Skipping file nonanomaly_a337.csv - too few frames (4 < 5)
# Processing file nonanomaly_a338.csv with 3 samples
# Processing file nonanomaly_a339.csv with 3 samples
# Processing file nonanomaly_a34.csv with 3 samples
# Processing file nonanomaly_a340.csv with 3 samples
# Skipping file nonanomaly_a341.csv - too few frames (4 < 5)
# Processing file nonanomaly_a342.csv with 3 samples
# Processing file nonanomaly_a343.csv with 3 samples
# Processing file nonanomaly_a344.csv with 3 samples
# Processing file nonanomaly_a345.csv with 3 samples
# Processing file nonanomaly_a346.csv with 3 samples
# Processing file nonanomaly_a347.csv with 3 samples
# Processing file nonanomaly_a348.csv with 3 samples
# Processing file nonanomaly_a349.csv with 3 samples
# Processing file nonanomaly_a35.csv with 4 samples
# Skipping file nonanomaly_a350.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a351.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a352.csv - too few frames (4 < 5)
# Processing file nonanomaly_a353.csv with 3 samples
# Processing file nonanomaly_a354.csv with 3 samples
# Processing file nonanomaly_a355.csv with 2 samples
# Processing file nonanomaly_a356.csv with 3 samples
# Processing file nonanomaly_a357.csv with 2 samples
# Processing file nonanomaly_a358.csv with 5 samples
# Skipping file nonanomaly_a359.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a36.csv - too few frames (4 < 5)
# Processing file nonanomaly_a360.csv with 1 samples
# Processing file nonanomaly_a361.csv with 3 samples
# Processing file nonanomaly_a362.csv with 3 samples
# Skipping file nonanomaly_a363.csv - too few frames (4 < 5)
# Processing file nonanomaly_a364.csv with 3 samples
# Processing file nonanomaly_a365.csv with 2 samples
# Processing file nonanomaly_a366.csv with 3 samples
# Processing file nonanomaly_a367.csv with 2 samples
# Processing file nonanomaly_a368.csv with 3 samples
# Processing file nonanomaly_a369.csv with 3 samples
# Processing file nonanomaly_a37.csv with 3 samples
# Processing file nonanomaly_a370.csv with 3 samples
# Skipping file nonanomaly_a371.csv - too few frames (4 < 5)
# Processing file nonanomaly_a372.csv with 2 samples
# Processing file nonanomaly_a373.csv with 3 samples
# Skipping file nonanomaly_a374.csv - too few frames (3 < 5)
# Processing file nonanomaly_a375.csv with 2 samples
# Processing file nonanomaly_a376.csv with 3 samples
# Processing file nonanomaly_a377.csv with 3 samples
# Processing file nonanomaly_a378.csv with 2 samples
# Processing file nonanomaly_a379.csv with 3 samples
# Processing file nonanomaly_a38.csv with 3 samples
# Processing file nonanomaly_a380.csv with 3 samples
# Processing file nonanomaly_a381.csv with 2 samples
# Processing file nonanomaly_a382.csv with 2 samples
# Processing file nonanomaly_a383.csv with 3 samples
# Processing file nonanomaly_a384.csv with 3 samples
# Processing file nonanomaly_a385.csv with 2 samples
# Processing file nonanomaly_a386.csv with 4 samples
# Processing file nonanomaly_a387.csv with 3 samples
# Processing file nonanomaly_a388.csv with 2 samples
# Processing file nonanomaly_a389.csv with 3 samples
# Processing file nonanomaly_a39.csv with 3 samples
# Processing file nonanomaly_a390.csv with 3 samples
# Processing file nonanomaly_a391.csv with 3 samples
# Skipping file nonanomaly_a392.csv - too few frames (4 < 5)
# Processing file nonanomaly_a393.csv with 2 samples
# Processing file nonanomaly_a394.csv with 3 samples
# Processing file nonanomaly_a395.csv with 3 samples
# Skipping file nonanomaly_a396.csv - too few frames (4 < 5)
# Processing file nonanomaly_a397.csv with 3 samples
# Processing file nonanomaly_a398.csv with 2 samples
# Processing file nonanomaly_a399.csv with 2 samples
# Processing file nonanomaly_a4.csv with 3 samples
# Skipping file nonanomaly_a40.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a400.csv - too few frames (4 < 5)
# Processing file nonanomaly_a401.csv with 3 samples
# Processing file nonanomaly_a402.csv with 3 samples
# Processing file nonanomaly_a403.csv with 3 samples
# Processing file nonanomaly_a404.csv with 2 samples
# Processing file nonanomaly_a405.csv with 3 samples
# Processing file nonanomaly_a406.csv with 4 samples
# Processing file nonanomaly_a407.csv with 3 samples
# Processing file nonanomaly_a408.csv with 2 samples
# Processing file nonanomaly_a409.csv with 2 samples
# Processing file nonanomaly_a41.csv with 2 samples
# Processing file nonanomaly_a410.csv with 2 samples
# Processing file nonanomaly_a411.csv with 3 samples
# Processing file nonanomaly_a412.csv with 2 samples
# Skipping file nonanomaly_a413.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a414.csv - too few frames (4 < 5)
# Processing file nonanomaly_a415.csv with 3 samples
# Processing file nonanomaly_a416.csv with 3 samples
# Processing file nonanomaly_a417.csv with 1 samples
# Processing file nonanomaly_a418.csv with 3 samples
# Processing file nonanomaly_a419.csv with 3 samples
# Processing file nonanomaly_a42.csv with 3 samples
# Processing file nonanomaly_a420.csv with 3 samples
# Processing file nonanomaly_a421.csv with 3 samples
# Processing file nonanomaly_a422.csv with 2 samples
# Processing file nonanomaly_a423.csv with 3 samples
# Processing file nonanomaly_a424.csv with 3 samples
# Skipping file nonanomaly_a425.csv - too few frames (4 < 5)
# Processing file nonanomaly_a426.csv with 3 samples
# Processing file nonanomaly_a427.csv with 3 samples
# Processing file nonanomaly_a428.csv with 3 samples
# Skipping file nonanomaly_a429.csv - too few frames (4 < 5)
# Processing file nonanomaly_a43.csv with 2 samples
# Processing file nonanomaly_a430.csv with 3 samples
# Processing file nonanomaly_a431.csv with 3 samples
# Processing file nonanomaly_a432.csv with 3 samples
# Processing file nonanomaly_a433.csv with 3 samples
# Processing file nonanomaly_a434.csv with 3 samples
# Processing file nonanomaly_a435.csv with 2 samples
# Processing file nonanomaly_a436.csv with 3 samples
# Processing file nonanomaly_a437.csv with 2 samples
# Processing file nonanomaly_a438.csv with 3 samples
# Processing file nonanomaly_a439.csv with 3 samples
# Processing file nonanomaly_a44.csv with 2 samples
# Processing file nonanomaly_a440.csv with 3 samples
# Processing file nonanomaly_a45.csv with 3 samples
# Processing file nonanomaly_a46.csv with 3 samples
# Processing file nonanomaly_a47.csv with 2 samples
# Processing file nonanomaly_a48.csv with 3 samples
# Processing file nonanomaly_a49.csv with 2 samples
# Skipping file nonanomaly_a5.csv - too few frames (3 < 5)
# Processing file nonanomaly_a50.csv with 3 samples
# Processing file nonanomaly_a51.csv with 2 samples
# Processing file nonanomaly_a52.csv with 3 samples
# Processing file nonanomaly_a53.csv with 3 samples
# Processing file nonanomaly_a54.csv with 3 samples
# Processing file nonanomaly_a55.csv with 3 samples
# Processing file nonanomaly_a56.csv with 4 samples
# Skipping file nonanomaly_a57.csv - too few frames (4 < 5)
# Processing file nonanomaly_a58.csv with 2 samples
# Processing file nonanomaly_a59.csv with 3 samples
# Processing file nonanomaly_a6.csv with 3 samples
# Skipping file nonanomaly_a60.csv - too few frames (4 < 5)
# Processing file nonanomaly_a61.csv with 3 samples
# Skipping file nonanomaly_a62.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a63.csv - too few frames (4 < 5)
# Processing file nonanomaly_a64.csv with 3 samples
# Processing file nonanomaly_a65.csv with 2 samples
# Processing file nonanomaly_a66.csv with 3 samples
# Processing file nonanomaly_a67.csv with 3 samples
# Skipping file nonanomaly_a68.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a69.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a7.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a70.csv - too few frames (4 < 5)
# Processing file nonanomaly_a71.csv with 3 samples
# Processing file nonanomaly_a72.csv with 2 samples
# Processing file nonanomaly_a73.csv with 2 samples
# Processing file nonanomaly_a74.csv with 2 samples
# Processing file nonanomaly_a75.csv with 2 samples
# Processing file nonanomaly_a76.csv with 3 samples
# Processing file nonanomaly_a77.csv with 3 samples
# Processing file nonanomaly_a78.csv with 2 samples
# Skipping file nonanomaly_a79.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a8.csv - too few frames (4 < 5)
# Processing file nonanomaly_a80.csv with 3 samples
# Processing file nonanomaly_a81.csv with 3 samples
# Processing file nonanomaly_a82.csv with 3 samples
# Processing file nonanomaly_a83.csv with 3 samples
# Processing file nonanomaly_a84.csv with 3 samples
# Processing file nonanomaly_a85.csv with 2 samples
# Skipping file nonanomaly_a86.csv - too few frames (4 < 5)
# Processing file nonanomaly_a87.csv with 3 samples
# Skipping file nonanomaly_a88.csv - too few frames (2 < 5)
# Skipping file nonanomaly_a89.csv - too few frames (4 < 5)
# Skipping file nonanomaly_a9.csv - too few frames (3 < 5)
# Processing file nonanomaly_a90.csv with 3 samples
# Processing file nonanomaly_a91.csv with 3 samples
# Processing file nonanomaly_a92.csv with 2 samples
# Processing file nonanomaly_a93.csv with 3 samples
# Processing file nonanomaly_a94.csv with 1 samples
# Processing file nonanomaly_a95.csv with 3 samples
# Processing file nonanomaly_a96.csv with 4 samples
# Processing file nonanomaly_a97.csv with 2 samples
# Processing file nonanomaly_a98.csv with 3 samples
# Processing file nonanomaly_a99.csv with 2 samples
# Generated 2292 samples from data_files\test

# %%
print('num of train_samples: {}'.format(len(train_data)))

print('num of test_samples: {}'.format(len(test_data)))
# Out:
# num of train_samples: 4087
# num of test_samples: 2292

# %%
train_generator = data_gen_obj.data_generator(train_data,batch_size=10,shuffle=True)

test_generator = data_gen_obj.data_generator(test_data,batch_size=10,shuffle=True)

# %%
Callback_Stop_Early = tf.keras.callbacks.EarlyStopping(monitor="loss",patience=3,mode='auto')

# %%
def get_model():
    # Load VGG16 without top layers and with appropriate input shape
    base_model = VGG16(weights='imagenet', 
                      include_top=False,
                      input_shape=(224, 224, 3))
    
    # Freeze VGG16 layers
    for layer in base_model.layers:
        layer.trainable = False
    
    # Create new model
    model = Sequential()
    
    # TimeDistributed wrapper for VGG16 to process each frame
    model.add(TimeDistributed(base_model, input_shape=(5, 224, 224, 3)))
    
    # Add Global Average Pooling to reduce dimensions
    model.add(TimeDistributed(GlobalAveragePooling2D()))
    
    # Add LSTM layers to process temporal information
    model.add(LSTM(256, return_sequences=True))
    model.add(Dropout(0.25))
    model.add(LSTM(128))
    model.add(Dropout(0.25))
    
    # Dense layers for classification
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax'))
    
    # Compile model
    model.compile(loss=categorical_crossentropy,
                 optimizer=Adam(learning_rate=0.0001),
                 metrics=['accuracy'])
    
    model.summary()
    return model

# %%
model = get_model()
# Out:
# c:\Users\srhan\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed                │ (None, 5, 7, 7, 512)   │    14,714,688 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ (None, 5, 512)         │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 5, 256)         │       787,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 5, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 128)            │       197,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │        66,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │         1,026 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,766,338 (60.14 MB)
#  Trainable params: 1,051,650 (4.01 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
from tensorflow.keras.utils import to_categorical

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_data) // 10,
    epochs=10,
    callbacks=[Callback_Stop_Early],
    validation_data=test_generator,
    validation_steps=len(test_data) // 10
)
# Out:
# Epoch 1/10
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 2134s 5s/step - accuracy: 0.6579 - loss: 0.6109 - val_accuracy: 0.8659 - val_loss: 0.3442
# Epoch 2/10
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 2185s 5s/step - accuracy: 0.8581 - loss: 0.3129 - val_accuracy: 0.8891 - val_loss: 0.2842
# Epoch 3/10
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 2186s 5s/step - accuracy: 0.8865 - loss: 0.2647 - val_accuracy: 0.8966 - val_loss: 0.2694
# Epoch 4/10
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 2114s 5s/step - accuracy: 0.8957 - loss: 0.2397 - val_accuracy: 0.8975 - val_loss: 0.2590
# Epoch 5/10
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 2084s 5s/step - accuracy: 0.9104 - loss: 0.2160 - val_accuracy: 0.9032 - val_loss: 0.2467
# Epoch 6/10
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 2111s 5s/step - accuracy: 0.9171 - loss: 0.1935 - val_accuracy: 0.9023 - val_loss: 0.2503
# Epoch 7/10
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 2110s 5s/step - accuracy: 0.9270 - loss: 0.1774 - val_accuracy: 0.9128 - val_loss: 0.2209
# Epoch 8/10
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 3476s 9s/step - accuracy: 0.9358 - loss: 0.1609 - val_accuracy: 0.9145 - val_loss: 0.2227
# Epoch 9/10
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 2761s 7s/step - accuracy: 0.9452 - loss: 0.1523 - val_accuracy: 0.9185 - val_loss: 0.2112
# Epoch 10/10
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 2076s 5s/step - accuracy: 0.9470 - loss: 0.1408 - val_accuracy: 0.9185 - val_loss: 0.2120

# %%
model.save('./VGG16+LSTM.keras')

# %%
sns.set()
# Summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.xticks(range(1, len(history.history['accuracy']) + 1))  # Adjusting to show all epochs
plt.show()

# Summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.xticks(range(1, len(history.history['loss']) + 1))  # Adjusting to show all epochs
plt.show()
